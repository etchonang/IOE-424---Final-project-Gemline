# %%
from google.colab import drive
import pandas as pd
from IPython.core.display import display
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import calendar
from datetime import datetime, timedelta
import re

# %% [markdown]
# ## Read in SKU + Sales Data

# %%
# ===============================================================
# 📂 BLOCK 2: MOUNT GOOGLE DRIVE & LOAD DATA FILES
# ===============================================================
drive.mount('/content/drive')

file_path1 = "/content/drive/MyDrive/IOE 424 (Gemline)/Data/SKU Data/SKU Attributes Report V2.xlsx"
file_path2 = "/content/drive/MyDrive/IOE 424 (Gemline)/Data/Sales and Pricing data/V3_Jan. 2022 to August 2025 Sales and Price data.xlsx"

# Load attribute file
df_sku_attributes = pd.read_excel(file_path1, engine="openpyxl")

# Category code → readable name
category_dict = {
    "*":      "COMMON",
    "BACKP":  "Backpack",
    "BBAGS":  "Business Bag",
    "COOL":   "Cooler",
    "DRINK":  "Drinkware",
    "DUF":    "Duffels",
    "FOOD":   "Food",
    "PAD":    "Padfolio",
    "STNRY":  "Stationery",
    "TECH":   "Technology",
    "TOTE":   "Totes",
    "TRAVL":  "Travel",
    "WRITE":  "Writing",
    "LFSTY":  "Lifestyle",
    "PPE":    "Personal Protective Equip.",
    "UMBR":   "Umbrellas",
    "HDWR":   "Headwear",
    "PKG":    "Packaging",
    "BLKTW":  "Blankets and Towels",
    "HOME":   "Home",
    "OFFCE":  "Office",
    "OUTDR":  "Outdoor",
    "SLWPK":  "Slings and Waist Packs",
}
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Merge Sales From 2022 - 2025

# %%
# ===============================================================
# 🧮 BLOCK 3: COMBINE SALES DATA (2022–2025)
# ===============================================================
sheet_names = [str(y) for y in range(2022, 2026)]
sheet_dict = pd.read_excel(file_path2, sheet_name=sheet_names, engine="openpyxl")

rename_map = {"Planned Ship Date/Time": "ShipDate", "Sales Qty": "SalesQty"}

frames = []
for name, df in sheet_dict.items():
    df = df.copy()
    df.columns = df.columns.str.strip()
    df = df.rename(columns={k: v for k, v in rename_map.items() if k in df.columns})

    if "ShipDate" in df.columns:
        df["ShipDate"] = pd.to_datetime(df["ShipDate"], errors="coerce")
    if "SalesQty" in df.columns:
        df["SalesQty"] = pd.to_numeric(df["SalesQty"], errors="coerce").fillna(0)
    if "Item" in df.columns:
        df["Item"] = df["Item"].astype(str).str.strip()

    df["year"] = int(name)
    frames.append(df)

combined_df = pd.concat(frames, ignore_index=True)

if "ShipDate" in combined_df.columns:
    combined_df = combined_df.dropna(subset=["ShipDate"]).reset_index(drop=True)

# %% [markdown]
# ## Remove's SKU's w/out Subcategory Desc + Discontinued

# %%
# ===============================================================
# 🧹 BLOCK 4: CLEAN ATTRIBUTE HEADERS & DROP EMPTY FIELDS
# ===============================================================
df_sku_attributes.columns = df_sku_attributes.columns.str.strip()
df_sku_attributes["Item"] = df_sku_attributes["Item"].astype(str).str.strip()

subcat_col = "Subcategory Desc"
status_col = "Status Code"

# If CommGroup2 exists, we keep it, but do NOT filter on it anymore
commgroup2_col = "CommGroup2 Desc" if "CommGroup2 Desc" in df_sku_attributes.columns else None

before = len(df_sku_attributes)

# ✅ Only enforce: Subcategory Desc must exist + not blank
df_sku_attributes = df_sku_attributes[
    df_sku_attributes[subcat_col].astype(str).str.strip() != ""
]
df_sku_attributes = df_sku_attributes.dropna(subset=[subcat_col])

after = len(df_sku_attributes)

print(f"Removed {before - after} rows with empty '{subcat_col}'.")
print(f"Remaining rows (active only): {len(df_sku_attributes)}")
# Out:
# Removed 8 rows with empty 'Subcategory Desc'.
# Remaining rows (active only): 2401

# %% [markdown]
# ## Category Expanded Added + Intro Code Changed

# %%
# ===============================================================
# 🧭 BLOCK 5: CLEAN & ENRICH ATTRIBUTE DATA (No CommGroup2; All Categories)
# ===============================================================
def find_col(cols, target):
    t = target.lower().replace(' ', '').replace('_', '')
    for c in cols:
        if c.lower().replace(' ', '').replace('_', '') == t:
            return c
    raise KeyError(f"Column '{target}' not found.")

def find_col_optional(cols, target):
    try:
        return find_col(cols, target)
    except KeyError:
        return None

# --- Locate required/optional columns
item_col       = find_col(df_sku_attributes.columns, "Item")
category_col   = find_col(df_sku_attributes.columns, "Category")
subcat_col     = find_col(df_sku_attributes.columns, "Subcategory Desc")
intro_code_col = find_col(df_sku_attributes.columns, "Intro Code")
commgroup2_col = find_col_optional(df_sku_attributes.columns, "CommGroup2 Desc")  # optional now

# --- Standardize core text fields (only those that exist)
df_tmp = df_sku_attributes.copy()
for c in [item_col, category_col, subcat_col, intro_code_col, commgroup2_col]:
    if c is not None and c in df_tmp.columns:
        df_tmp[c] = df_tmp[c].astype(str).str.strip()

# --- Preserve raw intro code for OOC detection
df_tmp["Intro Code (Raw)"] = df_tmp[intro_code_col].astype(str).str.strip().str.upper()

# --- Expand category codes → readable names
cat_upper = df_tmp[category_col].str.upper()
df_tmp["Category (Expanded)"] = cat_upper.map(category_dict).fillna(df_tmp[category_col])

# --- Parse Intro Codes (e.g., "JAN 22" → Timestamp)
MONTHS = {m: i for i, m in enumerate(
    ["JAN","FEB","MAR","APR","MAY","JUN","JUL","AUG","SEP","OCT","NOV","DEC"], start=1)}

def parse_intro_code(code: str):
    if not code or str(code).upper() in {"NA", "NAN"}:
        return pd.NaT
    m = re.match(r'^\s*([A-Za-z]{3})\s*(\d{2})\s*$', str(code))
    if not m:
        return pd.NaT
    mon_abbr, yy = m.group(1).upper(), m.group(2)
    mon = MONTHS.get(mon_abbr)
    if not mon:
        return pd.NaT
    year = 2000 + int(yy)
    try:
        return pd.Timestamp(year=year, month=mon, day=1)
    except Exception:
        return pd.NaT

df_tmp["Intro_ParsedDate"] = df_tmp[intro_code_col].map(parse_intro_code)
df_tmp[intro_code_col] = df_tmp["Intro_ParsedDate"].dt.strftime("%b %Y")

# --- Canonical item key
df_tmp["Item_norm"] = df_tmp[item_col].astype(str).str.strip()

# ✅ NOTE:
# We no longer filter to Backpack and we no longer enforce/require CommGroup2.
# Any later logic should use Category (Expanded) and Subcategory Desc only.

# %%
# ===============================================================
# 🔗 BLOCK 6: MERGE SALES DATA WITH ATTRIBUTE DATA (No CommGroup2 dependency)
# ===============================================================
combined_df = combined_df.copy()
combined_df["Item_key"] = combined_df["Item"].astype(str).str.strip()

# --- Build the attribute slice columns dynamically ---
attr_cols = [item_col, "Item_norm", category_col, "Category (Expanded)",
             subcat_col, "Intro_ParsedDate", intro_code_col, "Intro Code (Raw)"]

# include CommGroup2 only if it exists
if ('CommGroup2 Desc' in df_tmp.columns) or (commgroup2_col is not None and commgroup2_col in df_tmp.columns):
    attr_cols.insert(attr_cols.index(subcat_col) + 1, commgroup2_col)  # place next to subcat

# Deduplicate by Item_norm, keep latest intro
attrs_slice = (
    df_tmp[attr_cols]
      .sort_values(["Item_norm", "Intro_ParsedDate"], na_position="last")
      .drop_duplicates(subset=["Item_norm"], keep="last")
)

# --- Build rename map safely (only for cols that are present) ---
rename_map = {
    item_col: "Item_attr",
    category_col: "Category",
    subcat_col: "Subcategory Desc",
    intro_code_col: "Intro Code",
}
if ("CommGroup2 Desc" in attrs_slice.columns) or (commgroup2_col in attrs_slice.columns):
    rename_map[commgroup2_col] = "CommGroup2 Desc"

attrs_slice = attrs_slice.rename(columns=rename_map)

# --- Merge onto sales ---
merged_sales = combined_df.merge(
    attrs_slice.rename(columns={"Item_norm": "Item_key"}),
    on="Item_key",
    how="left"
)

merged_sales["Item"] = merged_sales["Item_key"]
merged_sales = merged_sales.drop(columns=["Item_key"])

# ✅ NEW: ensure CommGroup2 Desc exists even if attributes didn’t have it
if "CommGroup2 Desc" not in merged_sales.columns:
    merged_sales["CommGroup2 Desc"] = "N/A"

# --- Diagnostics ---
print(f"Merged rows: {len(merged_sales):,}")
sample_cols = [c for c in ["Category", "Category (Expanded)", "Subcategory Desc",
                           "CommGroup2 Desc", "Intro Code", "Intro_ParsedDate"]
               if c in merged_sales.columns]
print("Sample columns now present:", sample_cols)

unmatched = merged_sales["Category"].isna().sum()
print(f"Unmatched sales rows (no attribute hit): {unmatched:,}")

# Drop unmatched for downstream simplicity
before_rows = len(merged_sales)
unmatched_mask = merged_sales["Category"].isna()
dropped_rows = int(unmatched_mask.sum())
merged_sales = merged_sales[~unmatched_mask].reset_index(drop=True)

print(f"Safety Check: Dropped unmatched sales rows: {dropped_rows:,}")
print(f"Remaining merged sales rows: {len(merged_sales):,}")
# Out:
# Merged rows: 624,603
# Sample columns now present: ['Category', 'Category (Expanded)', 'Subcategory Desc', 'CommGroup2 Desc', 'Intro Code', 'Intro_ParsedDate']
# Unmatched sales rows (no attribute hit): 205,216
# Safety Check: Dropped unmatched sales rows: 205,216
# Remaining merged sales rows: 419,387

# %%
# ===============================================================
# 🚫 BLOCK 6A: DROP OOC / PPE / PAD / <NA> / PRE-2022 INTRO CODES / NO-COLOR / NO-SUBCATEGORY
# ===============================================================
removed_counts = {}

# 1️⃣ Intro Code = OOC*
if "Intro Code (Raw)" in merged_sales.columns:
    mask_ooc = merged_sales["Intro Code (Raw)"].astype(str).str.upper().str.startswith("OOC")
else:
    mask_ooc = pd.Series(False, index=merged_sales.index)
removed_counts["Intro Code = OOC*"] = int(mask_ooc.sum())

# 2️⃣ Category = PPE or PAD
mask_badcat = merged_sales["Category"].astype(str).str.upper().isin(["PPE", "PAD"])
removed_counts["Category in {PPE, PAD}"] = int(mask_badcat.sum())

# 3️⃣ Category = <NA>
mask_na_cat = merged_sales["Category"].isna()
removed_counts["Category = <NA>"] = int(mask_na_cat.sum())

# 4️⃣ Intro Code (Parsed Date) before Jan 2022
if "Intro_ParsedDate" in merged_sales.columns:
    cutoff_date = pd.Timestamp(2022, 1, 1)
    mask_pre2022 = merged_sales["Intro_ParsedDate"].notna() & (merged_sales["Intro_ParsedDate"] < cutoff_date)
else:
    mask_pre2022 = pd.Series(False, index=merged_sales.index)
removed_counts["Intro Code before Jan 2022"] = int(mask_pre2022.sum())

# 5️⃣ Color missing / blank → drop (check nulls BEFORE casting to str)
if "Color" in merged_sales.columns:
    col_color = merged_sales["Color"]
    mask_nocolor = (
        col_color.isna() |
        col_color.astype(str).str.strip().eq("") |
        col_color.astype(str).str.lower().str.strip().isin({"nan", "none"})
    )
else:
    mask_nocolor = pd.Series(False, index=merged_sales.index)
removed_counts["Color missing/blank"] = int(mask_nocolor.sum())

# 6️⃣ Subcategory missing / blank → drop (needed for Category→Subcategory analysis)
if "Subcategory Desc" in merged_sales.columns:
    col_sub = merged_sales["Subcategory Desc"]
    mask_no_subcat = (
        col_sub.isna() |
        col_sub.astype(str).str.strip().eq("") |
        col_sub.astype(str).str.lower().str.strip().isin({"nan", "none"})
    )
else:
    mask_no_subcat = pd.Series(False, index=merged_sales.index)
removed_counts["Subcategory missing/blank"] = int(mask_no_subcat.sum())

# 🧹 Apply all drops
drop_mask = mask_ooc | mask_badcat | mask_na_cat | mask_pre2022 | mask_nocolor | mask_no_subcat
before_rows = len(merged_sales)
merged_sales = merged_sales[~drop_mask].reset_index(drop=True)

print("\nSummary of removed sales rows:")
for k, v in removed_counts.items():
    print(f"  {k}: {v}")
print(f"[Dropping] Remaining sales rows: {len(merged_sales):,}")

# Rows by year (if present)
if "year" in merged_sales.columns:
    print("[Dropping] Rows by year:")
    print(merged_sales["year"].value_counts().sort_index())
# Out:
# Summary of removed sales rows:
#   Intro Code = OOC*: 1756
#   Category in {PPE, PAD}: 0
#   Category = <NA>: 0
#   Intro Code before Jan 2022: 265130
#   Color missing/blank: 0
#   Subcategory missing/blank: 0
# [Dropping] Remaining sales rows: 152,501
# [Dropping] Rows by year:
# year
# 2022    12545
# 2023    28911
# 2024    57569
# 2025    53476
# Name: count, dtype: int64

# %% [markdown]
# ## 3 Level Filtered Analysis on Backpacks

# %%
# ===============================================================
# 📈 Monthly plots by (Subcategory, CommGroup2)
#    — Intros ≥ Jan 2022, Quarterly x-axis, ≤10 SKUs only
# ===============================================================
# Ensure ShipDate is datetime
merged_sales["ShipDate"] = pd.to_datetime(merged_sales["ShipDate"], errors="coerce")

# Keep only Backpacks with valid intros after Jan 2022
cutoff = pd.Timestamp(2022, 1, 1)
backp_sales = merged_sales[
    (merged_sales["Category (Expanded)"] == "Backpack")
    & (merged_sales["Intro_ParsedDate"].notna())
    & (merged_sales["Intro_ParsedDate"] >= cutoff)
].copy()

# Map SKU → intro date
sku_intro_map = (
    backp_sales[["Item", "Intro_ParsedDate"]]
    .drop_duplicates(subset=["Item"])
    .set_index("Item")["Intro_ParsedDate"]
    .to_dict()
)

# Unique (Subcategory, CommGroup2) pairs
pairs = (
    backp_sales[["Subcategory Desc", "CommGroup2 Desc"]]
    .dropna()
    .drop_duplicates()
    .itertuples(index=False, name=None)
)

for sub, grp2 in pairs:
    # Slice data for this subcategory/group
    sub_df = backp_sales[
        (backp_sales["Subcategory Desc"] == sub) &
        (backp_sales["CommGroup2 Desc"] == grp2)
    ].copy()

    # Monthly aggregation
    sub_df["Month"] = sub_df["ShipDate"].dt.to_period("M").dt.to_timestamp()
    grouped = sub_df.groupby(["Month", "Item"], as_index=False)["SalesQty"].sum()
    pivot_df = grouped.pivot(index="Month", columns="Item", values="SalesQty").fillna(0)

    # Skip empty or overcrowded graphs (>10 SKUs)
    n_skus = len(pivot_df.columns)
    if n_skus == 0:
        print(f"(No sales to plot for: {sub} | {grp2})")
        continue
    if n_skus > 10:
        print(f"(Skipping {sub} | {grp2}: {n_skus} SKUs)")
        continue

    # Collect intro dates and define x-axis span
    panel_skus = list(pivot_df.columns)
    panel_intros = {sku: sku_intro_map.get(sku) for sku in panel_skus}
    valid_intro_list = [dt for dt in panel_intros.values() if pd.notna(dt)]

    xmin_sales, xmax_sales = pivot_df.index.min(), pivot_df.index.max()
    if valid_intro_list:
        xmin_all = min(xmin_sales, min(valid_intro_list))
        xmax_all = max(xmax_sales, max(valid_intro_list))
    else:
        xmin_all, xmax_all = xmin_sales, xmax_sales

    # --- Plot ---
    plt.figure(figsize=(12, 6))

    # Plot each SKU line (with intro in legend)
    for sku in panel_skus:
        intro_dt = panel_intros.get(sku)
        label = f"{sku} ({intro_dt:%b %Y})" if pd.notna(intro_dt) else f"{sku} (intro: n/a)"
        plt.plot(pivot_df.index, pivot_df[sku], linewidth=1.4, label=label)

    # Axes setup
    pad_days = pd.Timedelta(days=10)
    plt.xlim(xmin_all - pad_days, xmax_all + pad_days)

    y_top = float(pivot_df.max().max()) if pivot_df.values.size else 0.0
    if y_top <= 0:
        y_top = 1.0
    x_span = (xmax_all - xmin_all) if xmax_all > xmin_all else pd.Timedelta(days=1)
    x_offset = x_span * 0.015

    # Intro markers
    for sku, intro_dt in panel_intros.items():
        if pd.notna(intro_dt):
            plt.axvline(intro_dt, linestyle="--", linewidth=1.0, alpha=0.6)
            plt.text(
                intro_dt + x_offset, y_top * 1.05,
                intro_dt.strftime("%b %Y"),
                rotation=30, ha="left", va="bottom",
                fontsize=8, alpha=0.9, clip_on=False
            )

    # === Quarterly x-axis ticks ===
    ax = plt.gca()
    ax.xaxis.set_major_locator(mdates.MonthLocator(interval=3))  # every 3 months
    ax.xaxis.set_major_formatter(mdates.DateFormatter("%b %Y"))  # e.g. "Jan 2023"
    plt.xticks(rotation=45, ha="right")

    # Cosmetics
    plt.ylim(top=y_top * 1.2)
    plt.title(f"Backpack Sales by SKU — {sub} | {grp2}  ({n_skus} SKUs)")
    plt.xlabel("Month")
    plt.ylabel("Sales Quantity")
    plt.grid(True, alpha=0.3)
    plt.legend(loc="upper right", fontsize=8, ncol=1)
    plt.tight_layout()
    plt.show()
# Out:
# (Skipping Commuter | Laptop: 28 SKUs)
# (Skipping Campus | Laptop: 14 SKUs)
# (Skipping Event | Cinchpack: 17 SKUs)

# %%
# ===============================================================
# Cannibalization — Category → Subcategory (with intro fallback)
# ===============================================================
import pandas as pd, numpy as np, matplotlib.pyplot as plt, matplotlib.dates as mdates

# ---- knobs ----
CAT_COL   = 'Category (Expanded)'   # expanded category name
SUB_COL   = 'Subcategory Desc'
DATE_MIN  = pd.Timestamp(2022, 1, 1)
WIN_PRE   = 3     # months before intro
WIN_POST  = 3     # months after intro
MAX_LINES = 14    # max SKUs on a plot

# ---- required cols ----
_required = {'Item','ShipDate','SalesQty',CAT_COL,SUB_COL,'Intro_ParsedDate'}
missing = [c for c in _required if c not in merged_sales.columns]
if missing:
    raise ValueError(f"merged_sales is missing required columns: {missing}")

# ---- prep monthly panel & intro fallback ----
sales = merged_sales.copy()
sales['ShipDate'] = pd.to_datetime(sales['ShipDate'], errors='coerce')
sales = sales.dropna(subset=['ShipDate'])
sales['Month'] = sales['ShipDate'].dt.to_period('M').dt.to_timestamp()

# Use Intro_ParsedDate if present, else fallback to first observed sales month
first_sale = (sales.groupby('Item', as_index=False)
                   .agg(FirstSale=('Month','min')))
sales = sales.merge(first_sale, on='Item', how='left')
sales['Intro_Use'] = np.where(sales['Intro_ParsedDate'].notna(),
                              sales['Intro_ParsedDate'],
                              sales['FirstSale'])

# Keep only labeled rows and intros in/after DATE_MIN
sales = sales[(sales[CAT_COL].notna()) &
              (sales[SUB_COL].notna()) &
              (sales['Intro_Use'] >= DATE_MIN)].copy()

# Monthly SKU x subcategory
monthly = (sales.groupby(['Month','Item',CAT_COL,SUB_COL], dropna=False)['SalesQty']
                .sum()
                .reset_index())

# SKU meta at intro
sku_meta = (sales.groupby('Item', as_index=False)
                 .agg(Intro_Use=('Intro_Use','first'),
                      Cat=(CAT_COL,'first'),
                      Sub=(SUB_COL,'first')))

# helper: month window
def month_window(center_month, k_pre=3, k_post=3):
    center = pd.Timestamp(center_month).to_period('M').to_timestamp()
    pre  = [ (center - pd.DateOffset(months=i)).to_period('M').to_timestamp() for i in range(1, k_pre+1) ]
    post = [ (center + pd.DateOffset(months=i)).to_period('M').to_timestamp() for i in range(1, k_post+1) ]
    return sorted(pre), sorted(post)

# ---- per-intro cannibalization math ----
records = []
for _, r in sku_meta.iterrows():
    sku   = r['Item']
    intro = r['Intro_Use']
    cat   = r['Cat']
    sub   = r['Sub']
    if pd.isna(intro) or pd.isna(cat) or pd.isna(sub):
        continue

    pre_m, post_m = month_window(intro, WIN_PRE, WIN_POST)

    same_sub = (monthly[CAT_COL].eq(cat) & monthly[SUB_COL].eq(sub))
    pre_exist  = monthly[same_sub & monthly['Month'].isin(pre_m)  & (monthly['Item'] != sku)]
    post_exist = monthly[same_sub & monthly['Month'].isin(post_m) & (monthly['Item'] != sku)]
    post_new   = monthly[(monthly['Item']==sku) & monthly['Month'].isin(post_m)]

    S_pre  = float(pre_exist['SalesQty'].sum())  if len(pre_exist)  else 0.0
    S_post = float(post_exist['SalesQty'].sum()) if len(post_exist) else 0.0
    S_new  = float(post_new['SalesQty'].sum())   if len(post_new)   else 0.0

    pct = (np.nan if S_pre==0 else (S_post - S_pre) / S_pre)

    records.append({
        'Item_New': sku,
        'Intro_Month': pd.Timestamp(intro).to_period('M').to_timestamp(),
        CAT_COL: cat,
        SUB_COL: sub,
        'Sales_Pre_Intro': S_pre,
        'Sales_Post_Intro': S_post,
        'New_SKU_Sales': S_new,
        'Delta_Sales_Excl_New_SKU': pct
    })

canni_subcat = (pd.DataFrame.from_records(records)
                .sort_values([CAT_COL, SUB_COL, 'Intro_Month'])
                .reset_index(drop=True))

# ✅ SHOW EVERYTHING (no head())
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

print("Cannibalization events (ALL rows, ALL categories):")
display(canni_subcat)

# ---- roll-ups (no cannibalization ratio anymore) ----
subcat_summary = (
    canni_subcat.groupby([CAT_COL, SUB_COL], as_index=False)
                .agg({
                    'Item_New': 'count',
                    'Delta_Sales_Excl_New_SKU': 'mean'
                })
                .rename(columns={
                    'Item_New': 'N_Intro',
                    'Delta_Sales_Excl_New_SKU': 'Avg_Delta_Sales_Excl_New_SKU'
                })
)
print("\nSubcategory summary:")
display(subcat_summary)

category_summary = (
    canni_subcat.groupby([CAT_COL], as_index=False)
                .agg({
                    'Item_New': 'count',
                    'Delta_Sales_Excl_New_SKU': 'mean'
                })
                .rename(columns={
                    'Item_New': 'N_Intro',
                    'Delta_Sales_Excl_New_SKU': 'Avg_Delta_Sales_Excl_New_SKU'
                })
)
print("\nCategory summary:")
display(category_summary)
# Out:
# Cannibalization events (ALL rows, ALL categories):
#         Item_New Intro_Month     Category (Expanded)     Subcategory Desc  \
# 0     101198-001  2022-06-01                Backpack               Campus
# 1     101200-001  2022-06-01                Backpack               Campus
# 2     102308-001  2024-07-01                Backpack               Campus
# 3     102308-622  2024-07-01                Backpack               Campus
# 4     102310-001  2024-07-01                Backpack               Campus
# 5     102310-389  2024-07-01                Backpack               Campus
# 6     102310-696  2024-07-01                Backpack               Campus
# 7     102310-917  2024-07-01                Backpack               Campus
# 8     102310-955  2024-07-01                Backpack               Campus
# 9     102266-001  2025-04-01                Backpack               Campus
# 10    102266-252  2025-04-01                Backpack               Campus
# 11    102266-410  2025-04-01                Backpack               Campus
# 12    102266-622  2025-04-01                Backpack               Campus
# 13    102627-001  2025-05-01                Backpack               Campus
# 14    102627-101  2025-05-01                Backpack               Campus
# 15    102627-532  2025-05-01                Backpack               Campus
# 16    102310-449  2025-07-01                Backpack               Campus
# 17    102310-533  2025-07-01                Backpack               Campus
# 18    102521-001  2025-07-01                Backpack               Campus
# 19    101323-001  2022-06-01                Backpack             Commuter
# 20    101325-001  2022-06-01                Backpack             Commuter
# 21    101201-001  2022-08-01                Backpack             Commuter
# 22    101201-498  2022-08-01                Backpack             Commuter
# 23    100806-410  2023-01-01                Backpack             Commuter
# 24    101431-001  2023-08-01                Backpack             Commuter
# 25    101885-001  2024-01-01                Backpack             Commuter
# 26    101886-001  2024-01-01                Backpack             Commuter
# 27    101728-001  2024-04-01                Backpack             Commuter
# 28    101958-001  2024-07-01                Backpack             Commuter
# 29    102309-290  2024-07-01                Backpack             Commuter
# 30    102309-867  2024-07-01                Backpack             Commuter
# 31    102311-001  2024-07-01                Backpack             Commuter
# 32    102311-955  2024-07-01                Backpack             Commuter
# 33    102250-001  2025-01-01                Backpack             Commuter
# 34    102251-001  2025-01-01                Backpack             Commuter
# 35    102251-410  2025-01-01                Backpack             Commuter
# 36    102252-001  2025-01-01                Backpack             Commuter
# 37    102252-410  2025-01-01                Backpack             Commuter
# 38    102442-743  2025-01-01                Backpack             Commuter
# 39    102443-001  2025-01-01                Backpack             Commuter
# 40    102444-001  2025-01-01                Backpack             Commuter
# 41    102504-001  2025-04-01                Backpack             Commuter
# 42    102505-001  2025-04-01                Backpack             Commuter
# 43    102506-001  2025-04-01                Backpack             Commuter
# 44    102507-001  2025-04-01                Backpack             Commuter
# 45    100806-078  2025-07-01                Backpack             Commuter
# 46    101886-909  2025-07-01                Backpack             Commuter
# 47    102311-917  2025-07-01                Backpack             Commuter
# 48    102445-001  2025-07-01                Backpack             Commuter
# 49    102775-634  2025-07-01                Backpack             Commuter
# 50    102586-400  2025-07-01                Backpack             Computer
# 51    102587-001  2025-07-01                Backpack             Computer
# 52    102587-400  2025-07-01                Backpack             Computer
# 53    102588-001  2025-07-01                Backpack             Computer
# 54    101635-320  2023-04-01                Backpack                Event
# 55    101635-430  2023-04-01                Backpack                Event
# 56    101635-610  2023-04-01                Backpack                Event
# 57    101638-031  2023-04-01                Backpack                Event
# 58    101638-320  2023-04-01                Backpack                Event
# 59    101638-430  2023-04-01                Backpack                Event
# 60    101638-610  2023-04-01                Backpack                Event
# 61    101635-001  2024-04-01                Backpack                Event
# 62    101638-001  2024-04-01                Backpack                Event
# 63    102063-001  2024-07-01                Backpack                Event
# 64    102066-001  2024-07-01                Backpack                Event
# 65    102234-001  2024-09-01                Backpack                Event
# 66    102234-387  2024-09-01                Backpack                Event
# 67    102234-410  2024-09-01                Backpack                Event
# 68    102234-430  2024-09-01                Backpack                Event
# 69    102234-518  2024-09-01                Backpack                Event
# 70    102234-610  2024-09-01                Backpack                Event
# 71    102234-669  2024-09-01                Backpack                Event
# 72    102234-723  2024-09-01                Backpack                Event
# 73    102234-828  2024-09-01                Backpack                Event
# 74    102235-001  2024-09-01                Backpack                Event
# 75    102235-410  2024-09-01                Backpack                Event
# 76    102235-430  2024-09-01                Backpack                Event
# 77    102235-610  2024-09-01                Backpack                Event
# 78    102235-669  2024-09-01                Backpack                Event
# 79    100492-410  2025-04-01                Backpack                Event
# 80    100492-430  2025-04-01                Backpack                Event
# 81    100492-610  2025-04-01                Backpack                Event
# 82    102267-001  2025-04-01                Backpack                Event
# 83    102267-410  2025-04-01                Backpack                Event
# 84    101556-001  2024-07-01                Backpack              Outdoor
# 85    100964-497  2025-01-01                Backpack              Outdoor
# 86    100964-901  2025-01-01                Backpack              Outdoor
# 87    100965-497  2025-01-01                Backpack              Outdoor
# 88    100965-901  2025-01-01                Backpack              Outdoor
# 89    101472-021  2023-01-01                Backpack            Specialty
# 90    101245-001  2024-04-01                Backpack            Specialty
# 91    102732-001  2025-07-01                Backpack                Sport
# 92    102732-519  2025-07-01                Backpack                Sport
# 93    102732-917  2025-07-01                Backpack                Sport
# 94    101663-001  2023-01-01                Backpack               Travel
# 95    101423-001  2023-08-01                Backpack               Travel
# 96    101424-001  2023-08-01                Backpack               Travel
# 97    101571-001  2023-08-01                Backpack               Travel
# 98    100153-001  2024-01-01                Backpack               Travel
# 99    100154-001  2024-01-01                Backpack               Travel
# 100   101831-418  2024-01-01                Backpack               Travel
# 101   102312-001  2024-07-01                Backpack               Travel
# 102   102312-917  2024-07-01                Backpack               Travel
# 103   102313-001  2024-07-01                Backpack               Travel
# 104   102313-955  2024-07-01                Backpack               Travel
# 105   102314-928  2024-07-01                Backpack               Travel
# 106   102224-001  2025-01-01                Backpack               Travel
# 107   102224-266  2025-01-01                Backpack               Travel
# 108   102281-001  2025-01-01                Backpack               Travel
# 109   100463-001  2025-04-01                Backpack               Travel
# 110   102629-001  2025-05-01                Backpack               Travel
# 111   102629-279  2025-05-01                Backpack               Travel
# 112   102629-917  2025-05-01                Backpack               Travel
# 113   100960-211  2023-08-01     Blankets and Towels                 Home
# 114   101755-410  2023-08-01     Blankets and Towels                 Home
# 115   101755-900  2023-08-01     Blankets and Towels                 Home
# 116   101756-001  2023-08-01     Blankets and Towels                 Home
# 117   101756-274  2023-08-01     Blankets and Towels                 Home
# 118   101757-074  2023-08-01     Blankets and Towels                 Home
# 119   101755-074  2024-07-01     Blankets and Towels                 Home
# 120   101756-413  2024-07-01     Blankets and Towels                 Home
# 121   102152-274  2024-07-01     Blankets and Towels                 Home
# 122   102158-210  2024-07-01     Blankets and Towels                 Home
# 123   102158-278  2024-07-01     Blankets and Towels                 Home
# 124   102158-581  2024-07-01     Blankets and Towels                 Home
# 125   102158-958  2024-07-01     Blankets and Towels                 Home
# 126   102160-959  2024-07-01     Blankets and Towels                 Home
# 127   102161-155  2024-07-01     Blankets and Towels                 Home
# 128   102331-155  2025-01-01     Blankets and Towels                 Home
# 129   100990-524  2025-04-01     Blankets and Towels                 Home
# 130   100990-911  2025-04-01     Blankets and Towels                 Home
# 131   101756-239  2025-07-01     Blankets and Towels                 Home
# 132   101756-539  2025-07-01     Blankets and Towels                 Home
# 133   102160-217  2025-07-01     Blankets and Towels                 Home
# 134   102160-218  2025-07-01     Blankets and Towels                 Home
# 135   101364-179  2022-04-01     Blankets and Towels              Outdoor
# 136   101364-180  2022-04-01     Blankets and Towels              Outdoor
# 137   101364-181  2022-04-01     Blankets and Towels              Outdoor
# 138   101364-891  2023-04-01     Blankets and Towels              Outdoor
# 139   101703-591  2024-04-01     Blankets and Towels              Outdoor
# 140   101703-592  2024-04-01     Blankets and Towels              Outdoor
# 141   100988-941  2024-07-01     Blankets and Towels              Outdoor
# 142   101222-973  2025-01-01     Blankets and Towels              Outdoor
# 143   102165-111  2025-01-01     Blankets and Towels              Outdoor
# 144   101703-910  2025-04-01     Blankets and Towels              Outdoor
# 145   101703-911  2025-04-01     Blankets and Towels              Outdoor
# 146   100988-739  2025-07-01     Blankets and Towels              Outdoor
# 147   101363-538  2025-07-01     Blankets and Towels              Outdoor
# 148   100994-924  2023-04-01     Blankets and Towels    Sport and Fitness
# 149   102215-001  2024-04-01     Blankets and Towels    Sport and Fitness
# 150   102215-080  2024-04-01     Blankets and Towels    Sport and Fitness
# 151   102215-413  2024-04-01     Blankets and Towels    Sport and Fitness
# 152   102216-001  2024-04-01     Blankets and Towels    Sport and Fitness
# 153   102216-126  2024-04-01     Blankets and Towels    Sport and Fitness
# 154   102216-413  2024-04-01     Blankets and Towels    Sport and Fitness
# 155   102290-001  2024-09-01     Blankets and Towels    Sport and Fitness
# 156   102290-155  2024-09-01     Blankets and Towels    Sport and Fitness
# 157   102290-430  2024-09-01     Blankets and Towels    Sport and Fitness
# 158   102572-284  2025-01-01     Blankets and Towels    Sport and Fitness
# 159   102572-745  2025-01-01     Blankets and Towels    Sport and Fitness
# 160   102572-876  2025-01-01     Blankets and Towels    Sport and Fitness
# 161   102572-908  2025-01-01     Blankets and Towels    Sport and Fitness
# 162   102572-975  2025-01-01     Blankets and Towels    Sport and Fitness
# 163   100994-259  2025-04-01     Blankets and Towels    Sport and Fitness
# 164   100994-941  2025-04-01     Blankets and Towels    Sport and Fitness
# 165   102215-430  2025-04-01     Blankets and Towels    Sport and Fitness
# 166   102215-610  2025-04-01     Blankets and Towels    Sport and Fitness
# 167   101324-001  2022-06-01            Business Bag             Commuter
# 168   101430-001  2023-08-01            Business Bag             Commuter
# 169   101959-001  2024-07-01            Business Bag             Commuter
# 170   102061-001  2024-07-01            Business Bag             Commuter
# 171   102253-001  2025-01-01            Business Bag             Commuter
# 172   101988-001  2024-07-01                  Cooler             Backpack
# 173   102341-001  2025-01-01                  Cooler             Backpack
# 174   102342-001  2025-01-01                  Cooler             Backpack
# 175   102248-001  2024-09-01                  Cooler                  Box
# 176   102248-410  2024-09-01                  Cooler                  Box
# 177   102248-430  2024-09-01                  Cooler                  Box
# 178   102248-828  2024-09-01                  Cooler                  Box
# 179   102338-610  2025-01-01                  Cooler                  Box
# 180   102068-059  2024-04-01                  Cooler     Hard Sides Event
# 181   102069-059  2024-04-01                  Cooler     Hard Sides Event
# 182   102071-886  2024-04-01                  Cooler     Hard Sides Event
# 183   102071-887  2024-04-01                  Cooler     Hard Sides Event
# 184   102073-886  2024-04-01                  Cooler     Hard Sides Event
# 185   102073-887  2024-04-01                  Cooler     Hard Sides Event
# 186   102074-886  2024-04-01                  Cooler     Hard Sides Event
# 187   102074-887  2024-04-01                  Cooler     Hard Sides Event
# 188   102075-886  2024-04-01                  Cooler     Hard Sides Event
# 189   102075-887  2024-04-01                  Cooler     Hard Sides Event
# 190   102136-100  2024-04-01                  Cooler     Hard Sides Event
# 191   101641-876  2023-04-01                  Cooler  Hard Sides Personal
# 192   101641-886  2023-04-01                  Cooler  Hard Sides Personal
# 193   101641-887  2023-04-01                  Cooler  Hard Sides Personal
# 194   102070-590  2024-04-01                  Cooler  Hard Sides Personal
# 195   102070-946  2024-04-01                  Cooler  Hard Sides Personal
# 196   102247-001  2024-09-01                  Cooler                Lunch
# 197   102247-410  2024-09-01                  Cooler                Lunch
# 198   102247-430  2024-09-01                  Cooler                Lunch
# 199   102247-828  2024-09-01                  Cooler                Lunch
# 200   101034-001  2022-01-01                  Cooler     Soft Sides Event
# 201   101181-130  2022-01-01                  Cooler     Soft Sides Event
# 202   101182-130  2022-01-01                  Cooler     Soft Sides Event
# 203   101229-001  2022-04-01                  Cooler     Soft Sides Event
# 204   100176-777  2022-06-01                  Cooler     Soft Sides Event
# 205   100177-777  2022-06-01                  Cooler     Soft Sides Event
# 206   100178-777  2022-06-01                  Cooler     Soft Sides Event
# 207   100315-777  2022-06-01                  Cooler     Soft Sides Event
# 208   100427-777  2022-06-01                  Cooler     Soft Sides Event
# 209   100400-100  2023-01-01                  Cooler     Soft Sides Event
# 210   100401-100  2023-01-01                  Cooler     Soft Sides Event
# 211   100402-100  2023-01-01                  Cooler     Soft Sides Event
# 212   100403-100  2023-01-01                  Cooler     Soft Sides Event
# 213   101034-410  2023-01-01                  Cooler     Soft Sides Event
# 214   101439-100  2023-04-01                  Cooler     Soft Sides Event
# 215   101588-237  2023-04-01                  Cooler     Soft Sides Event
# 216   101608-001  2023-08-01                  Cooler     Soft Sides Event
# 217   101608-794  2023-08-01                  Cooler     Soft Sides Event
# 218   101609-001  2023-08-01                  Cooler     Soft Sides Event
# 219   101609-794  2023-08-01                  Cooler     Soft Sides Event
# 220   101610-001  2023-08-01                  Cooler     Soft Sides Event
# 221   101901-059  2023-08-01                  Cooler     Soft Sides Event
# 222   101930-130  2024-01-01                  Cooler     Soft Sides Event
# 223   101747-774  2024-04-01                  Cooler     Soft Sides Event
# 224   101748-774  2024-04-01                  Cooler     Soft Sides Event
# 225   101786-774  2024-04-01                  Cooler     Soft Sides Event
# 226   101787-774  2024-04-01                  Cooler     Soft Sides Event
# 227   102113-101  2024-04-01                  Cooler     Soft Sides Event
# 228   102114-276  2024-04-01                  Cooler     Soft Sides Event
# 229   102591-100  2025-04-01                  Cooler     Soft Sides Event
# 230   102592-100  2025-04-01                  Cooler     Soft Sides Event
# 231   102593-100  2025-04-01                  Cooler     Soft Sides Event
# 232   101034-078  2025-07-01                  Cooler     Soft Sides Event
# 233   102476-929  2025-07-01                  Cooler     Soft Sides Event
# 234   101032-001  2022-01-01                  Cooler  Soft Sides Personal
# 235   101033-001  2022-01-01                  Cooler  Soft Sides Personal
# 236   101180-130  2022-01-01                  Cooler  Soft Sides Personal
# 237   101180-920  2022-01-01                  Cooler  Soft Sides Personal
# 238   101189-001  2022-06-01                  Cooler  Soft Sides Personal
# 239   101220-038  2022-06-01                  Cooler  Soft Sides Personal
# 240   101220-039  2022-06-01                  Cooler  Soft Sides Personal
# 241   101220-777  2022-06-01                  Cooler  Soft Sides Personal
# 242   101248-022  2022-08-01                  Cooler  Soft Sides Personal
# 243   101032-410  2023-01-01                  Cooler  Soft Sides Personal
# 244   101033-410  2023-01-01                  Cooler  Soft Sides Personal
# 245   101475-021  2023-01-01                  Cooler  Soft Sides Personal
# 246   101615-001  2023-06-01                  Cooler  Soft Sides Personal
# 247   101615-381  2023-06-01                  Cooler  Soft Sides Personal
# 248   101616-001  2023-06-01                  Cooler  Soft Sides Personal
# 249   101616-381  2023-06-01                  Cooler  Soft Sides Personal
# 250   101606-001  2023-08-01                  Cooler  Soft Sides Personal
# 251   101606-794  2023-08-01                  Cooler  Soft Sides Personal
# 252   101607-001  2023-08-01                  Cooler  Soft Sides Personal
# 253   101248-001  2024-04-01                  Cooler  Soft Sides Personal
# 254   101746-774  2024-04-01                  Cooler  Soft Sides Personal
# 255   101749-774  2024-04-01                  Cooler  Soft Sides Personal
# 256   102590-100  2025-04-01                  Cooler  Soft Sides Personal
# 257   101032-078  2025-07-01                  Cooler  Soft Sides Personal
# 258   102542-001  2025-07-01                  Cooler  Soft Sides Personal
# 259   102542-387  2025-07-01                  Cooler  Soft Sides Personal
# 260   102542-430  2025-07-01                  Cooler  Soft Sides Personal
# 261   102542-610  2025-07-01                  Cooler  Soft Sides Personal
# 262   102542-828  2025-07-01                  Cooler  Soft Sides Personal
# 263   101987-001  2024-07-01                  Cooler                 Tote
# 264   102339-031  2025-01-01                  Cooler                 Tote
# 265   102340-031  2025-01-01                  Cooler                 Tote
# 266   101223-009  2022-01-01               Drinkware     Active Hydration
# 267   101223-104  2022-01-01               Drinkware     Active Hydration
# 268   101224-009  2022-01-01               Drinkware     Active Hydration
# 269   101224-104  2022-01-01               Drinkware     Active Hydration
# 270   101412-373  2022-06-01               Drinkware     Active Hydration
# 271   101412-763  2022-06-01               Drinkware     Active Hydration
# 272   101412-782  2022-06-01               Drinkware     Active Hydration
# 273   101361-100  2023-01-01               Drinkware     Active Hydration
# 274   101361-128  2023-01-01               Drinkware     Active Hydration
# 275   101361-492  2024-01-01               Drinkware     Active Hydration
# 276   101726-100  2024-01-01               Drinkware     Active Hydration
# 277   101726-128  2024-01-01               Drinkware     Active Hydration
# 278   101726-492  2024-01-01               Drinkware     Active Hydration
# 279   101938-001  2024-04-01               Drinkware     Active Hydration
# 280   102138-100  2024-04-01               Drinkware     Active Hydration
# 281   102138-945  2024-04-01               Drinkware     Active Hydration
# 282   102139-100  2024-04-01               Drinkware     Active Hydration
# 283   102139-944  2024-04-01               Drinkware     Active Hydration
# 284   101687-006  2024-07-01               Drinkware     Active Hydration
# 285   101687-763  2024-07-01               Drinkware     Active Hydration
# 286   102322-000  2024-07-01               Drinkware     Active Hydration
# 287   102322-791  2024-07-01               Drinkware     Active Hydration
# 288   102323-000  2024-07-01               Drinkware     Active Hydration
# 289   102323-791  2024-07-01               Drinkware     Active Hydration
# 290   102403-594  2025-01-01               Drinkware     Active Hydration
# 291   102403-694  2025-01-01               Drinkware     Active Hydration
# 292   102404-006  2025-01-01               Drinkware     Active Hydration
# 293   102404-100  2025-01-01               Drinkware     Active Hydration
# 294   102405-006  2025-01-01               Drinkware     Active Hydration
# 295   102405-100  2025-01-01               Drinkware     Active Hydration
# 296   102345-430  2025-04-01               Drinkware     Active Hydration
# 297   102345-828  2025-04-01               Drinkware     Active Hydration
# 298   102346-430  2025-04-01               Drinkware     Active Hydration
# 299   102346-828  2025-04-01               Drinkware     Active Hydration
# 300   102404-022  2025-04-01               Drinkware     Active Hydration
# 301   102404-255  2025-04-01               Drinkware     Active Hydration
# 302   102404-256  2025-04-01               Drinkware     Active Hydration
# 303   102404-257  2025-04-01               Drinkware     Active Hydration
# 304   102683-200  2025-07-01               Drinkware     Active Hydration
# 305   102683-650  2025-07-01               Drinkware     Active Hydration
# 306   102683-913  2025-07-01               Drinkware     Active Hydration
# 307   102684-209  2025-07-01               Drinkware     Active Hydration
# 308   102684-228  2025-07-01               Drinkware     Active Hydration
# 309   102686-238  2025-07-01               Drinkware     Active Hydration
# 310   102686-470  2025-07-01               Drinkware     Active Hydration
# 311   101284-000  2022-01-01               Drinkware              Barware
# 312   101285-000  2022-01-01               Drinkware              Barware
# 313   101287-000  2022-01-01               Drinkware              Barware
# 314   101288-000  2022-01-01               Drinkware              Barware
# 315   101360-128  2023-04-01               Drinkware              Barware
# 316   102117-133  2024-07-01               Drinkware              Barware
# 317   102226-001  2025-01-01               Drinkware              Barware
# 318   102226-119  2025-01-01               Drinkware              Barware
# 319   102226-594  2025-01-01               Drinkware              Barware
# 320   102226-694  2025-01-01               Drinkware              Barware
# 321   102227-001  2025-01-01               Drinkware              Barware
# 322   102227-119  2025-01-01               Drinkware              Barware
# 323   102228-001  2025-01-01               Drinkware              Barware
# 324   102228-119  2025-01-01               Drinkware              Barware
# 325   102441-000  2025-01-01               Drinkware              Barware
# 326   100485-109  2025-07-01               Drinkware              Barware
# 327   100485-545  2025-07-01               Drinkware              Barware
# 328   100485-969  2025-07-01               Drinkware              Barware
# 329   102202-000  2024-09-01               Drinkware      Beverage Bottle
# 330   100370-274  2022-04-01               Drinkware       Coffee and Tea
# 331   101303-006  2022-04-01               Drinkware       Coffee and Tea
# 332   101303-100  2022-04-01               Drinkware       Coffee and Tea
# 333   101466-009  2022-08-01               Drinkware       Coffee and Tea
# 334   101466-104  2022-08-01               Drinkware       Coffee and Tea
# 335   101357-001  2023-01-01               Drinkware       Coffee and Tea
# 336   101357-100  2023-01-01               Drinkware       Coffee and Tea
# 337   101357-415  2023-01-01               Drinkware       Coffee and Tea
# 338   101357-630  2023-01-01               Drinkware       Coffee and Tea
# 339   101670-088  2023-01-01               Drinkware       Coffee and Tea
# 340   101670-274  2023-01-01               Drinkware       Coffee and Tea
# 341   101611-001  2023-06-01               Drinkware       Coffee and Tea
# 342   101611-294  2023-06-01               Drinkware       Coffee and Tea
# 343   101612-001  2023-06-01               Drinkware       Coffee and Tea
# 344   101612-294  2023-06-01               Drinkware       Coffee and Tea
# 345   101939-001  2024-04-01               Drinkware       Coffee and Tea
# 346   102087-001  2024-04-01               Drinkware       Coffee and Tea
# 347   102089-001  2024-04-01               Drinkware       Coffee and Tea
# 348   100276-791  2024-07-01               Drinkware       Coffee and Tea
# 349   101950-001  2024-07-01               Drinkware       Coffee and Tea
# 350   101950-119  2024-07-01               Drinkware       Coffee and Tea
# 351   101950-594  2024-07-01               Drinkware       Coffee and Tea
# 352   101950-694  2024-07-01               Drinkware       Coffee and Tea
# 353   100276-137  2025-01-01               Drinkware       Coffee and Tea
# 354   101357-430  2025-01-01               Drinkware       Coffee and Tea
# 355   101357-669  2025-01-01               Drinkware       Coffee and Tea
# 356   101357-828  2025-01-01               Drinkware       Coffee and Tea
# 357   100482-022  2025-04-01               Drinkware       Coffee and Tea
# 358   100482-255  2025-04-01               Drinkware       Coffee and Tea
# 359   100482-256  2025-04-01               Drinkware       Coffee and Tea
# 360   100481-109  2025-07-01               Drinkware       Coffee and Tea
# 361   100481-545  2025-07-01               Drinkware       Coffee and Tea
# 362   100481-969  2025-07-01               Drinkware       Coffee and Tea
# 363   100604-109  2025-07-01               Drinkware       Coffee and Tea
# 364   100604-545  2025-07-01               Drinkware       Coffee and Tea
# 365   100604-969  2025-07-01               Drinkware       Coffee and Tea
# 366   102680-229  2025-07-01               Drinkware       Coffee and Tea
# 367   102680-238  2025-07-01               Drinkware       Coffee and Tea
# 368   102755-109  2025-07-01               Drinkware       Coffee and Tea
# 369   102761-009  2025-07-01               Drinkware       Coffee and Tea
# 370   102761-104  2025-07-01               Drinkware       Coffee and Tea
# 371   102761-467  2025-07-01               Drinkware       Coffee and Tea
# 372   100740-104  2022-01-01               Drinkware   Everyday Hydration
# 373   101355-001  2023-01-01               Drinkware   Everyday Hydration
# 374   101355-100  2023-01-01               Drinkware   Everyday Hydration
# 375   101355-415  2023-01-01               Drinkware   Everyday Hydration
# 376   101355-630  2023-01-01               Drinkware   Everyday Hydration
# 377   101355-733  2023-01-01               Drinkware   Everyday Hydration
# 378   101358-001  2023-01-01               Drinkware   Everyday Hydration
# 379   101358-100  2023-01-01               Drinkware   Everyday Hydration
# 380   101358-415  2023-01-01               Drinkware   Everyday Hydration
# 381   101358-630  2023-01-01               Drinkware   Everyday Hydration
# 382   101358-733  2023-01-01               Drinkware   Everyday Hydration
# 383   100275-791  2023-04-01               Drinkware   Everyday Hydration
# 384   100740-791  2023-04-01               Drinkware   Everyday Hydration
# 385   101541-100  2023-04-01               Drinkware   Everyday Hydration
# 386   101541-762  2023-04-01               Drinkware   Everyday Hydration
# 387   101542-100  2023-04-01               Drinkware   Everyday Hydration
# 388   101542-762  2023-04-01               Drinkware   Everyday Hydration
# 389   101543-100  2023-04-01               Drinkware   Everyday Hydration
# 390   101543-762  2023-04-01               Drinkware   Everyday Hydration
# 391   101544-100  2023-04-01               Drinkware   Everyday Hydration
# 392   101544-762  2023-04-01               Drinkware   Everyday Hydration
# 393   101668-006  2023-04-01               Drinkware   Everyday Hydration
# 394   101668-100  2023-04-01               Drinkware   Everyday Hydration
# 395   101899-006  2023-08-01               Drinkware   Everyday Hydration
# 396   101899-100  2023-08-01               Drinkware   Everyday Hydration
# 397   101941-009  2023-09-01               Drinkware   Everyday Hydration
# 398   101941-104  2023-09-01               Drinkware   Everyday Hydration
# 399   101998-006  2024-01-01               Drinkware   Everyday Hydration
# 400   101998-100  2024-01-01               Drinkware   Everyday Hydration
# 401   102106-088  2024-04-01               Drinkware   Everyday Hydration
# 402   102140-100  2024-04-01               Drinkware   Everyday Hydration
# 403   102140-944  2024-04-01               Drinkware   Everyday Hydration
# 404   101952-001  2024-07-01               Drinkware   Everyday Hydration
# 405   101952-119  2024-07-01               Drinkware   Everyday Hydration
# 406   101952-594  2024-07-01               Drinkware   Everyday Hydration
# 407   101952-694  2024-07-01               Drinkware   Everyday Hydration
# 408   102118-133  2024-07-01               Drinkware   Everyday Hydration
# 409   100275-137  2025-01-01               Drinkware   Everyday Hydration
# 410   101355-430  2025-01-01               Drinkware   Everyday Hydration
# 411   101355-669  2025-01-01               Drinkware   Everyday Hydration
# 412   101355-828  2025-01-01               Drinkware   Everyday Hydration
# 413   101941-137  2025-01-01               Drinkware   Everyday Hydration
# 414   101998-022  2025-04-01               Drinkware   Everyday Hydration
# 415   101998-255  2025-04-01               Drinkware   Everyday Hydration
# 416   101998-256  2025-04-01               Drinkware   Everyday Hydration
# 417   102600-009  2025-04-01               Drinkware   Everyday Hydration
# 418   102600-104  2025-04-01               Drinkware   Everyday Hydration
# 419   102600-548  2025-04-01               Drinkware   Everyday Hydration
# 420   102600-791  2025-04-01               Drinkware   Everyday Hydration
# 421   102670-022  2025-04-01               Drinkware   Everyday Hydration
# 422   102670-255  2025-04-01               Drinkware   Everyday Hydration
# 423   102670-256  2025-04-01               Drinkware   Everyday Hydration
# 424   102670-257  2025-04-01               Drinkware   Everyday Hydration
# 425   102651-001  2025-05-01               Drinkware   Everyday Hydration
# 426   102651-100  2025-05-01               Drinkware   Everyday Hydration
# 427   102651-407  2025-05-01               Drinkware   Everyday Hydration
# 428   102652-001  2025-05-01               Drinkware   Everyday Hydration
# 429   102652-100  2025-05-01               Drinkware   Everyday Hydration
# 430   102652-407  2025-05-01               Drinkware   Everyday Hydration
# 431   102654-001  2025-05-01               Drinkware   Everyday Hydration
# 432   102654-100  2025-05-01               Drinkware   Everyday Hydration
# 433   102654-848  2025-05-01               Drinkware   Everyday Hydration
# 434   102682-200  2025-07-01               Drinkware   Everyday Hydration
# 435   102682-650  2025-07-01               Drinkware   Everyday Hydration
# 436   102682-913  2025-07-01               Drinkware   Everyday Hydration
# 437   102685-209  2025-07-01               Drinkware   Everyday Hydration
# 438   102685-228  2025-07-01               Drinkware   Everyday Hydration
# 439   102230-001  2025-01-01               Drinkware            Hydration
# 440   102230-119  2025-01-01               Drinkware            Hydration
# 441   102230-594  2025-01-01               Drinkware            Hydration
# 442   102230-694  2025-01-01               Drinkware            Hydration
# 443   102138-492  2025-04-01               Drinkware            Hydration
# 444   102589-059  2025-04-01               Drinkware            Hydration
# 445   102589-944  2025-04-01               Drinkware            Hydration
# 446   102229-001  2025-01-01               Drinkware                  Mug
# 447   102229-119  2025-01-01               Drinkware                  Mug
# 448   102229-594  2025-01-01               Drinkware                  Mug
# 449   102229-694  2025-01-01               Drinkware                  Mug
# 450   101559-001  2024-07-01                 Duffels              Outdoor
# 451   101246-022  2022-08-01                 Duffels            Specialty
# 452   101169-001  2022-06-01                 Duffels                Sport
# 453   101211-001  2022-06-01                 Duffels                Sport
# 454   101781-001  2024-04-01                 Duffels                Sport
# 455   102285-001  2025-04-01                 Duffels                Sport
# 456   102285-100  2025-04-01                 Duffels                Sport
# 457   102285-410  2025-04-01                 Duffels                Sport
# 458   102285-430  2025-04-01                 Duffels                Sport
# 459   102285-610  2025-04-01                 Duffels                Sport
# 460   102286-001  2025-04-01                 Duffels                Sport
# 461   102286-410  2025-04-01                 Duffels                Sport
# 462   102286-430  2025-04-01                 Duffels                Sport
# 463   102733-001  2025-07-01                 Duffels                Sport
# 464   102733-427  2025-07-01                 Duffels                Sport
# 465   102734-917  2025-07-01                 Duffels                Sport
# 466   101916-418  2024-07-01                 Duffels               Travel
# 467   101960-001  2024-07-01                 Duffels               Travel
# 468   102315-928  2024-07-01                 Duffels               Travel
# 469   102316-928  2024-07-01                 Duffels               Travel
# 470   102317-928  2024-07-01                 Duffels               Travel
# 471   102318-928  2024-07-01                 Duffels               Travel
# 472   100159-866  2025-01-01                 Duffels               Travel
# 473   100160-001  2025-01-01                 Duffels               Travel
# 474   100161-001  2025-01-01                 Duffels               Travel
# 475   102388-001  2025-04-01                 Duffels               Travel
# 476   102508-001  2025-04-01                 Duffels               Travel
# 477   102511-001  2025-04-01                 Duffels               Travel
# 478   101833-418  2024-01-01                 Duffels            Weekender
# 479   101964-925  2024-07-01                 Duffels            Weekender
# 480   102225-001  2025-01-01                 Duffels            Weekender
# 481   102225-266  2025-01-01                 Duffels            Weekender
# 482   102269-001  2025-04-01                 Duffels            Weekender
# 483   102269-410  2025-04-01                 Duffels            Weekender
# 484   102269-622  2025-04-01                 Duffels            Weekender
# 485   102628-001  2025-05-01                 Duffels            Weekender
# 486   102628-101  2025-05-01                 Duffels            Weekender
# 487   102628-635  2025-05-01                 Duffels            Weekender
# 488   102698-001  2025-07-01                 Duffels            Weekender
# 489   102776-624  2025-07-01                 Duffels            Weekender
# 490   101290-130  2022-06-01                    Food         All Occasion
# 491   101290-237  2022-06-01                    Food         All Occasion
# 492   101290-920  2022-06-01                    Food         All Occasion
# 493   100667-001  2024-07-01                    Food         All Occasion
# 494   101019-001  2024-07-01                    Food         All Occasion
# 495   101027-281  2024-07-01                    Food         All Occasion
# 496   101685-240  2024-07-01                    Food         All Occasion
# 497   101699-001  2024-07-01                    Food         All Occasion
# 498   101832-001  2024-07-01                    Food         All Occasion
# 499   101832-100  2024-07-01                    Food         All Occasion
# 500   101876-001  2024-07-01                    Food         All Occasion
# 501   101876-275  2024-07-01                    Food         All Occasion
# 502   101876-410  2024-07-01                    Food         All Occasion
# 503   101877-001  2024-07-01                    Food         All Occasion
# 504   101877-275  2024-07-01                    Food         All Occasion
# 505   101877-410  2024-07-01                    Food         All Occasion
# 506   101934-777  2024-07-01                    Food         All Occasion
# 507   102330-001  2024-07-01                    Food         All Occasion
# 508   102330-119  2024-07-01                    Food         All Occasion
# 509   102330-594  2024-07-01                    Food         All Occasion
# 510   102330-694  2024-07-01                    Food         All Occasion
# 511   102334-001  2024-07-01                    Food         All Occasion
# 512   102334-100  2024-07-01                    Food         All Occasion
# 513   102352-101  2024-07-01                    Food         All Occasion
# 514   102376-214  2024-07-01                    Food         All Occasion
# 515   102378-006  2024-07-01                    Food         All Occasion
# 516   102378-107  2024-07-01                    Food         All Occasion
# 517   102379-006  2024-07-01                    Food         All Occasion
# 518   102379-107  2024-07-01                    Food         All Occasion
# 519   102379-415  2024-07-01                    Food         All Occasion
# 520   101876-078  2025-07-01                    Food         All Occasion
# 521   102796-119  2025-07-01                    Food             Gift Box
# 522   102817-128  2025-07-01                    Food             Gift Box
# 523   102818-128  2025-07-01                    Food             Gift Box
# 524   102819-128  2025-07-01                    Food             Gift Box
# 525   102870-101  2025-07-01                    Food             Gift Box
# 526   102884-959  2025-07-01                    Food             Gift Box
# 527   102792-390  2025-07-01                    Food             Gift Set
# 528   102792-610  2025-07-01                    Food             Gift Set
# 529   102792-706  2025-07-01                    Food             Gift Set
# 530   102792-917  2025-07-01                    Food             Gift Set
# 531   102793-001  2025-07-01                    Food             Gift Set
# 532   102795-101  2025-07-01                    Food             Gift Set
# 533   102816-410  2025-07-01                    Food             Gift Set
# 534   102816-430  2025-07-01                    Food             Gift Set
# 535   102824-001  2025-07-01                    Food             Gift Set
# 536   102824-100  2025-07-01                    Food             Gift Set
# 537   102824-412  2025-07-01                    Food             Gift Set
# 538   102824-843  2025-07-01                    Food             Gift Set
# 539   102825-610  2025-07-01                    Food             Gift Set
# 540   102852-214  2025-07-01                    Food             Gift Set
# 541   102853-101  2025-07-01                    Food             Gift Set
# 542   102855-119  2025-07-01                    Food             Gift Set
# 543   102855-594  2025-07-01                    Food             Gift Set
# 544   102856-001  2025-07-01                    Food             Gift Set
# 545   102856-119  2025-07-01                    Food             Gift Set
# 546   102857-594  2025-07-01                    Food             Gift Set
# 547   102888-101  2025-07-01                    Food             Gift Set
# 548   102889-101  2025-07-01                    Food             Gift Set
# 549   102890-101  2025-07-01                    Food             Gift Set
# 550   102326-214  2024-07-01                    Food             Seasonal
# 551   102351-101  2024-07-01                    Food             Seasonal
# 552   102377-006  2024-07-01                    Food             Seasonal
# 553   102377-107  2024-07-01                    Food             Seasonal
# 554   102377-415  2024-07-01                    Food             Seasonal
# 555   101565-101  2025-07-01                    Food             Seasonal
# 556   101906-101  2025-07-01                    Food             Seasonal
# 557   101984-100  2025-07-01                    Food             Seasonal
# 558   101524-215  2022-06-01                    Food          Starter Kit
# 559   100607-101  2024-07-01                    Food          Starter Kit
# 560   101011-262  2024-07-01                    Food          Starter Kit
# 561   101524-100  2024-07-01                    Food          Starter Kit
# 562   101524-714  2024-07-01                    Food          Starter Kit
# 563   102360-101  2024-07-01                    Food          Starter Kit
# 564   102362-101  2024-07-01                    Food          Starter Kit
# 565   102239-001  2024-07-01                Headwear                  Cap
# 566   102239-100  2024-07-01                Headwear                  Cap
# 567   102239-398  2024-07-01                Headwear                  Cap
# 568   102239-399  2024-07-01                Headwear                  Cap
# 569   102239-579  2024-07-01                Headwear                  Cap
# 570   102239-580  2024-07-01                Headwear                  Cap
# 571   102240-001  2024-07-01                Headwear                  Cap
# 572   102240-100  2024-07-01                Headwear                  Cap
# 573   102240-870  2024-07-01                Headwear                  Cap
# 574   102240-904  2024-07-01                Headwear                  Cap
# 575   102242-001  2024-07-01                Headwear                  Cap
# 576   102242-100  2024-07-01                Headwear                  Cap
# 577   102242-388  2024-07-01                Headwear                  Cap
# 578   102242-475  2024-07-01                Headwear                  Cap
# 579   102242-575  2024-07-01                Headwear                  Cap
# 580   102242-576  2024-07-01                Headwear                  Cap
# 581   102242-870  2024-07-01                Headwear                  Cap
# 582   102242-904  2024-07-01                Headwear                  Cap
# 583   102242-942  2024-07-01                Headwear                  Cap
# 584   102271-001  2024-07-01                Headwear                  Cap
# 585   102271-100  2024-07-01                Headwear                  Cap
# 586   102271-475  2024-07-01                Headwear                  Cap
# 587   102271-578  2024-07-01                Headwear                  Cap
# 588   102271-904  2024-07-01                Headwear                  Cap
# 589   102271-943  2024-07-01                Headwear                  Cap
# 590   102271-956  2024-07-01                Headwear                  Cap
# 591   102272-001  2024-07-01                Headwear                  Cap
# 592   102272-100  2024-07-01                Headwear                  Cap
# 593   102272-475  2024-07-01                Headwear                  Cap
# 594   102272-578  2024-07-01                Headwear                  Cap
# 595   102272-668  2024-07-01                Headwear                  Cap
# 596   102272-855  2024-07-01                Headwear                  Cap
# 597   102272-868  2024-07-01                Headwear                  Cap
# 598   102272-869  2024-07-01                Headwear                  Cap
# 599   102272-904  2024-07-01                Headwear                  Cap
# 600   102272-943  2024-07-01                Headwear                  Cap
# 601   102272-956  2024-07-01                Headwear                  Cap
# 602   102526-001  2025-01-01                Headwear                  Cap
# 603   102526-100  2025-01-01                Headwear                  Cap
# 604   102526-377  2025-01-01                Headwear                  Cap
# 605   102526-412  2025-01-01                Headwear                  Cap
# 606   102526-423  2025-01-01                Headwear                  Cap
# 607   102526-580  2025-01-01                Headwear                  Cap
# 608   102526-699  2025-01-01                Headwear                  Cap
# 609   102526-870  2025-01-01                Headwear                  Cap
# 610   102527-001  2025-01-01                Headwear                  Cap
# 611   102527-100  2025-01-01                Headwear                  Cap
# 612   102527-396  2025-01-01                Headwear                  Cap
# 613   102527-412  2025-01-01                Headwear                  Cap
# 614   102527-580  2025-01-01                Headwear                  Cap
# 615   102527-905  2025-01-01                Headwear                  Cap
# 616   102530-581  2025-01-01                Headwear                  Cap
# 617   102530-595  2025-01-01                Headwear                  Cap
# 618   102530-728  2025-01-01                Headwear                  Cap
# 619   102545-142  2025-01-01                Headwear                  Cap
# 620   102555-026  2025-01-01                Headwear                  Cap
# ...
# 1264                       NaN
# 1265                       NaN
# 1266                       NaN
# 1267                       NaN
# 1268                       NaN
# 1269                       NaN
# 1270                 -0.511450
# 1271                 -0.848552
# 1272                 -0.853007
# 1273                       NaN
# 1274                       NaN
# 1275                       NaN
# 1276                       NaN
# 1277                       NaN
# 1278                       NaN
# 1279                 -0.888679
# 1280                  0.423322
# 1281                  0.670130
# 1282                  0.538312
# 1283                  0.847552
# 1284                  0.856772
# 1285                  0.826256
# 1286                  0.827035
# 1287                  0.851188
# 1288                 -0.317542
# 1289                  0.701585
# 1290                  0.754475
# 1291                  0.691372
# 1292                  0.695074
# 1293                  0.398578
# 1294                  0.412634
# 1295                  0.411935
# 1296                  0.160876
# 1297                  0.160580
# 1298                  0.144943
# 1299                  0.101851
# 1300                  0.103207
# 1301                  0.106413
# 1302                  0.112209
# 1303                  0.104033
# 1304                  0.106573
# 1305                  0.093367
# 1306                  0.106327
# 1307                  0.113725
# 1308                  0.096869
# 1309                  0.101012
# 1310                  0.102739
# 1311                  0.110186
# 1312                  0.061283
# 1313                  0.105784
# 1314                  0.079804
# 1315                  0.046671
# 1316                 -0.410186
# 1317                 -0.416384
# 1318                 -0.429829
# 1319                 -0.408435
# 1320                 -0.436105
# 1321                 -0.412231
# 1322                 -0.409061
# 1323                 -0.408486
# 1324                 -0.409074
# 1325                 -0.408397
# 1326                 -0.409061
# 1327                       NaN
# 1328                  5.166102
# 1329                  3.131010
# 1330                  3.079075
# 1331                  2.670072
# 1332                  2.661659
# 1333                  3.006013
# 1334                  0.141853
# 1335                  0.207503
# 1336                  0.380406
# 1337                  0.381954
# 1338                 -0.527268
# 1339                200.894737
# 1340                202.157895
# 1341                203.789474
# 1342                140.973684
# 1343                133.315789
# 1344                178.473684
# 1345                186.289474
# 1346                399.526316
# 1347                373.105263
# 1348                 -0.408308
# 1349                 -0.354667
# 1350                 -0.300923
# 1351                 -0.316000
# 1352                       NaN
# 1353                       NaN
# 1354                       NaN
# 1355                       NaN
# 1356                       NaN
# 1357                       NaN
# 1358                       NaN
# 1359                       NaN
# 1360                       NaN
# 1361                       NaN
# 1362                       NaN
# 1363                       NaN
# 1364                       NaN
# 1365                       NaN
# 1366                       NaN
# 1367                       NaN
# 1368                       NaN
# 1369                       NaN
# 1370                       NaN
# 1371                       NaN
# 1372                       NaN
# 1373                  9.339801
# 1374                  9.340748
# 1375                  9.313772
# 1376                  9.326550
# 1377                  9.339801
# 1378                  9.332702
# 1379                  9.340748
# 1380                  7.495031
# 1381                  8.950308
# 1382                  9.340748
# 1383                  9.340748
# 1384                  9.340748
# 1385                  9.293422
# 1386                  9.340748
# 1387                  9.340748
# 1388                  9.340748
# 1389                  9.340748
# 1390                  9.331756
# 1391                  9.340748
# 1392                  9.340748
# 1393                  9.340274
# 1394                  9.292948
# 1395                  9.340274
# 1396                  9.061051
# 1397                  9.321817
# 1398                  9.216753
# 1399                  9.192144
# 1400                  9.340274
# 1401                  9.340274
# 1402                  9.333176
# 1403                  0.214350
# 1404                  0.209928
# 1405                  0.206102
# 1406                  0.190533
# 1407                  0.224383
# 1408                  0.218738
# 1409                       NaN
# 1410                       NaN
# 1411                  2.520822
# 1412                  2.493240
# 1413                  2.520281
# 1414                  2.131963
# 1415                  2.344511
# 1416                  2.382910
# 1417                  2.504056
# 1418                  2.518659
# 1419                  2.493780
# 1420                  2.519740
# 1421                  2.500811
# 1422                  2.439697
# 1423                  2.519740
# 1424                  2.519740
# 1425                  2.512169
# 1426                  0.558986
# 1427                       NaN
# 1428                       NaN
# 1429                       NaN
# 1430                       NaN
# Subcategory summary:
#        Category (Expanded)     Subcategory Desc  N_Intro  \
# 0                 Backpack               Campus       19
# 1                 Backpack             Commuter       31
# 2                 Backpack             Computer        4
# 3                 Backpack                Event       30
# 4                 Backpack              Outdoor        5
# 5                 Backpack            Specialty        2
# 6                 Backpack                Sport        3
# 7                 Backpack               Travel       19
# 8      Blankets and Towels                 Home       22
# 9      Blankets and Towels              Outdoor       13
# 10     Blankets and Towels    Sport and Fitness       19
# 11            Business Bag             Commuter        5
# 12                  Cooler             Backpack        3
# 13                  Cooler                  Box        5
# 14                  Cooler     Hard Sides Event       11
# 15                  Cooler  Hard Sides Personal        5
# 16                  Cooler                Lunch        4
# 17                  Cooler     Soft Sides Event       34
# 18                  Cooler  Soft Sides Personal       29
# 19                  Cooler                 Tote        3
# 20               Drinkware     Active Hydration       45
# 21               Drinkware              Barware       18
# 22               Drinkware      Beverage Bottle        1
# 23               Drinkware       Coffee and Tea       42
# 24               Drinkware   Everyday Hydration       67
# 25               Drinkware            Hydration        7
# 26               Drinkware                  Mug        4
# 27                 Duffels              Outdoor        1
# 28                 Duffels            Specialty        1
# 29                 Duffels                Sport       14
# 30                 Duffels               Travel       12
# 31                 Duffels            Weekender       12
# 32                    Food         All Occasion       31
# 33                    Food             Gift Box        6
# 34                    Food             Gift Set       23
# 35                    Food             Seasonal        8
# 36                    Food          Starter Kit        7
# 37                Headwear                  Cap       67
# 38                Headwear                 Knit        5
# 39                Headwear          Performance       40
# 40                Headwear              Trucker       55
# 41                    Home                Decor        5
# 42                    Home        Entertainment       11
# 43                    Home         Food Storage       13
# 44                    Home              Kitchen       27
# 45                    Home             Wellness       15
# 46                  Office              Desktop        5
# 47                  Office      Junior Padfolio        7
# 48                  Office    Standard Padfolio        8
# 49                 Outdoor                 Auto       18
# 50                 Outdoor                 Golf       49
# 51                 Outdoor          Home & Auto        1
# 52                 Outdoor     Patio and Picnic       21
# 53               Packaging              Accents        1
# 54               Packaging            Accessory        4
# 55               Packaging            Component        2
# 56               Packaging             Gift Box        1
# 57               Packaging            Kraft Box        4
# 58               Packaging              Writing        1
# 59  Slings and Waist Packs             Commuter        8
# 60  Slings and Waist Packs                Event       23
# 61  Slings and Waist Packs              Outdoor        2
# 62  Slings and Waist Packs                Sport        5
# 63  Slings and Waist Packs               Travel        3
# 64              Stationery             Gift Set       22
# 65              Stationery              Journal       12
# 66              Stationery             Notebook       18
# 67              Stationery            Packaging        2
# 68              Stationery                Smart        2
# 69              Stationery            Specialty        2
# 70              Technology            Accessory        7
# 71              Technology             Charging       35
# 72              Technology                Sound       29
# 73              Technology       Tech Accessory       16
# 74              Technology    Wireless Charging        4
# 75                   Totes          All Purpose        3
# 76                   Totes             Commuter        4
# 77                   Totes                Event       11
# 78                   Totes             Everyday      111
# 79                   Totes          Home & Auto        1
# 80                   Totes              Outdoor        7
# 81                   Totes            Specialty        8
# 82                   Totes                Sport        3
# 83                   Totes               Travel        5
# 84                  Travel              Amenity        1
# 85                  Travel                 Bags        4
# 86                  Travel              Luggage        3
# 87                  Travel         Organization       51
# 88                  Travel   Travel Accessories       12
# 89               Umbrellas              Compact       13
# 90               Umbrellas                 Golf       11
# 91               Umbrellas                Stick        6
# 92                 Writing            Ballpoint       40
# 93                 Writing           Rollerball       18
# 94                 Writing              Writing        4
#
#     Avg_Delta_Sales_Excl_New_SKU
# 0                       1.044835
# 1                       0.352175
# 2                            NaN
# 3                     257.133110
# 4                       5.455931
# 5                       0.160763
# 6                            NaN
# 7                       0.615760
# 8                    1425.239943
# 9                       0.960996
# 10                      2.024368
# 11                      0.136886
# 12                      0.439700
# 13                     -0.204960
# 14                           NaN
# 15                     29.936311
# 16                    935.000000
# 17                      0.561434
# 18                      0.825195
# 19                      0.810796
# 20                      0.137628
# 21                     -0.027069
# 22                           NaN
# 23                      0.243451
# 24                      1.222500
# 25                     11.429682
# 26                     92.263158
# 27                           NaN
# 28                           NaN
# 29                      0.735234
# 30                     15.087934
# 31                      0.605377
# 32                      1.354977
# 33                           NaN
# 34                           NaN
# 35                     14.206693
# 36                     13.710334
# 37                      0.482063
# 38                     12.767097
# 39                     32.459578
# 40                      2.015164
# 41                     -0.198438
# 42                      2.369192
# 43                     45.729602
# 44                     -0.147121
# 45                      0.335703
# 46                      4.168041
# 47                      1.245543
# 48                      0.130351
# 49                      1.132203
# 50                      5.973960
# 51                           NaN
# 52                     28.696676
# 53                           NaN
# 54                           NaN
# 55                           NaN
# 56                           NaN
# 57                     -0.450945
# 58                           NaN
# 59                      0.045612
# 60                      2.440358
# 61                           NaN
# 62                     -0.756522
# 63                     -0.272876
# 64                      0.879768
# 65                   6167.909091
# 66                      0.893644
# 67                           NaN
# 68                           NaN
# 69                     -0.603659
# 70                     49.369694
# 71                      0.289285
# 72                      1.200945
# 73                      1.263220
# 74                           NaN
# 75                           NaN
# 76                     -0.594148
# 77                      0.356672
# 78                      0.146434
# 79                           NaN
# 80                      0.334819
# 81                     -0.353893
# 82                           NaN
# 83                           NaN
# 84                           NaN
# 85                     -0.737670
# 86                           NaN
# 87                      0.130442
# 88                      1.845307
# 89                    155.165109
# 90                           NaN
# 91                           NaN
# 92                      7.736511
# 93                      2.342569
# 94                           NaN
# Category summary:
#        Category (Expanded)  N_Intro  Avg_Delta_Sales_Excl_New_SKU
# 0                 Backpack      113                     78.535725
# 1      Blankets and Towels       54                    611.756885
# 2             Business Bag        5                      0.136886
# 3                   Cooler       94                     43.604053
# 4                Drinkware      184                      2.608349
# 5                  Duffels       40                      5.615347
# 6                     Food       75                      5.276077
# 7                 Headwear      167                     14.621161
# 8                     Home       71                     11.242923
# 9                   Office       20                      1.557970
# 10                 Outdoor       89                     10.191383
# 11               Packaging       13                     -0.450945
# 12  Slings and Waist Packs       41                      1.518530
# 13              Stationery       58                   1330.999158
# 14              Technology       91                      4.369992
# 15                   Totes      153                      0.135228
# 16                  Travel       71                      0.392687
# 17               Umbrellas       30                    155.165109
# 18                 Writing       62                      6.076836

# %%
# Sales_Pre_Intro = Total subcategory sales BEFORE the new item launched.
# Sales_Post_Intro - Total subcategory sales AFTER the new item launched (using all existing SKUs only — excluding the new SKU).
# New_SKU_Sales = Sales of the new item itself in the same post-intro window.
# Delta_Sales_Excl_New_SKU = Percent change in subcategory sales excluding the new SKU:

# %%
# ===============================================================
# 🔍 Filter for negative Delta_Sales_Excl_New_SKU values
# ===============================================================

negatives = (
    canni_subcat[canni_subcat["Delta_Sales_Excl_New_SKU"] < 0]
    .sort_values("Delta_Sales_Excl_New_SKU")
    .reset_index(drop=True)
)

print("Rows where existing subcategory sales declined after intro:")
display(negatives)
# Out:
# Rows where existing subcategory sales declined after intro:
#        Item_New Intro_Month     Category (Expanded)     Subcategory Desc  \
# 0    102850-001  2025-08-01              Technology             Charging
# 1    102849-001  2025-08-01              Technology             Charging
# 2    102848-001  2025-08-01              Technology             Charging
# 3    102851-001  2025-08-01              Technology             Charging
# 4    102847-001  2025-08-01              Technology             Charging
# 5    102765-860  2025-08-01                Headwear          Performance
# 6    102765-038  2025-08-01                Headwear          Performance
# 7    102537-605  2025-08-01                Headwear              Trucker
# 8    102534-638  2025-08-01                Headwear          Performance
# 9    102534-417  2025-08-01                Headwear          Performance
# 10   102529-331  2025-08-01                Headwear          Performance
# 11   102531-390  2025-08-01                Headwear          Performance
# 12   102810-913  2025-08-01                Headwear                  Cap
# 13   102810-579  2025-08-01                Headwear                  Cap
# 14   102527-605  2025-08-01                Headwear                  Cap
# 15   102526-309  2025-08-01                Headwear                  Cap
# 16   102535-636  2025-08-01                Headwear              Trucker
# 17   101620-214  2023-01-01                    Home        Entertainment
# 18   102515-001  2025-07-01                   Totes            Specialty
# 19   102486-410  2025-07-01                   Totes            Specialty
# 20   101876-078  2025-07-01                    Food         All Occasion
# 21   101210-001  2022-06-01                  Travel         Organization
# 22   101276-001  2022-04-01              Stationery             Notebook
# 23   102719-098  2025-07-01              Technology       Tech Accessory
# 24   102699-001  2025-07-01                  Travel                 Bags
# 25   102597-001  2025-07-01                  Travel                 Bags
# 26   102681-100  2025-07-01              Technology       Tech Accessory
# 27   102672-100  2025-07-01              Technology       Tech Accessory
# 28   102687-001  2025-07-01              Technology       Tech Accessory
# 29   102559-001  2025-07-01              Technology       Tech Accessory
# 30   100988-739  2025-07-01     Blankets and Towels              Outdoor
# 31   101363-538  2025-07-01     Blankets and Towels              Outdoor
# 32   100805-275  2023-04-01  Slings and Waist Packs             Commuter
# 33   102484-410  2025-07-01                   Totes             Commuter
# 34   102331-155  2025-01-01     Blankets and Towels                 Home
# 35   102484-001  2025-07-01                   Totes             Commuter
# 36   101034-078  2025-07-01                  Cooler     Soft Sides Event
# 37   102731-001  2025-07-01  Slings and Waist Packs                Sport
# 38   102476-929  2025-07-01                  Cooler     Soft Sides Event
# 39   100485-109  2025-07-01               Drinkware              Barware
# 40   101032-078  2025-07-01                  Cooler  Soft Sides Personal
# 41   100485-969  2025-07-01               Drinkware              Barware
# 42   100485-545  2025-07-01               Drinkware              Barware
# 43   102731-917  2025-07-01  Slings and Waist Packs                Sport
# 44   102731-427  2025-07-01  Slings and Waist Packs                Sport
# 45   102731-519  2025-07-01  Slings and Waist Packs                Sport
# 46   102761-104  2025-07-01               Drinkware       Coffee and Tea
# 47   102761-467  2025-07-01               Drinkware       Coffee and Tea
# 48   102761-009  2025-07-01               Drinkware       Coffee and Tea
# 49   102680-229  2025-07-01               Drinkware       Coffee and Tea
# 50   100604-545  2025-07-01               Drinkware       Coffee and Tea
# 51   100481-545  2025-07-01               Drinkware       Coffee and Tea
# 52   102755-109  2025-07-01               Drinkware       Coffee and Tea
# 53   100481-969  2025-07-01               Drinkware       Coffee and Tea
# 54   100604-969  2025-07-01               Drinkware       Coffee and Tea
# 55   100481-109  2025-07-01               Drinkware       Coffee and Tea
# 56   100604-109  2025-07-01               Drinkware       Coffee and Tea
# 57   102680-238  2025-07-01               Drinkware       Coffee and Tea
# 58   102542-610  2025-07-01                  Cooler  Soft Sides Personal
# 59   102542-001  2025-07-01                  Cooler  Soft Sides Personal
# 60   102542-430  2025-07-01                  Cooler  Soft Sides Personal
# 61   102542-387  2025-07-01                  Cooler  Soft Sides Personal
# 62   102542-828  2025-07-01                  Cooler  Soft Sides Personal
# 63   100161-001  2025-01-01                 Duffels               Travel
# 64   100160-001  2025-01-01                 Duffels               Travel
# 65   101445-214  2023-01-01                 Outdoor     Patio and Picnic
# 66   100159-866  2025-01-01                 Duffels               Travel
# 67   102808-054  2025-07-01                    Home             Wellness
# 68   102455-021  2025-07-01              Technology             Charging
# 69   102808-268  2025-07-01                    Home             Wellness
# 70   102808-267  2025-07-01                    Home             Wellness
# 71   102808-529  2025-07-01                    Home             Wellness
# 72   101565-101  2025-07-01                    Food             Seasonal
# 73   100988-941  2024-07-01     Blankets and Towels              Outdoor
# 74          980  2022-06-01               Packaging            Kraft Box
# 75   102733-001  2025-07-01                 Duffels                Sport
# 76   102311-917  2025-07-01                Backpack             Commuter
# 77   102733-427  2025-07-01                 Duffels                Sport
# 78   102734-917  2025-07-01                 Duffels                Sport
# 79   102033-143  2025-07-01                   Totes             Everyday
# 80   102445-001  2025-07-01                Backpack             Commuter
# 81   101886-909  2025-07-01                Backpack             Commuter
# 82   100806-078  2025-07-01                Backpack             Commuter
# 83   102775-634  2025-07-01                Backpack             Commuter
# 84   102036-143  2025-07-01                   Totes             Everyday
# 85   100804-078  2025-07-01                   Totes             Everyday
# 86   102688-101  2025-07-01                   Totes             Everyday
# 87   101926-410  2025-07-01                   Totes             Everyday
# 88   102032-143  2025-07-01                   Totes             Everyday
# 89   102485-101  2025-07-01                   Totes             Everyday
# 90   101802-410  2025-07-01                   Totes             Everyday
# 91   102525-054  2025-01-01              Stationery            Specialty
# 92   102686-470  2025-07-01               Drinkware     Active Hydration
# 93   102683-913  2025-07-01               Drinkware     Active Hydration
# 94   102683-650  2025-07-01               Drinkware     Active Hydration
# 95   102686-238  2025-07-01               Drinkware     Active Hydration
# 96   102684-228  2025-07-01               Drinkware     Active Hydration
# 97   102683-200  2025-07-01               Drinkware     Active Hydration
# 98   102684-209  2025-07-01               Drinkware     Active Hydration
# 99   102253-001  2025-01-01            Business Bag             Commuter
# 100  101886-001  2024-01-01                Backpack             Commuter
# 101  102034-001  2024-01-01                    Home              Kitchen
# 102  101885-001  2024-01-01                Backpack             Commuter
# 103  102034-050  2024-01-01                    Home              Kitchen
# 104  101412-373  2022-06-01               Drinkware     Active Hydration
# 105  102349-410  2025-01-01                    Home              Kitchen
# 106  102034-101  2024-01-01                    Home              Kitchen
# 107  102159-582  2024-07-01              Stationery             Notebook
# 108  102648-001  2025-07-01              Stationery             Gift Set
# 109  102523-612  2025-07-01              Stationery             Gift Set
# 110  102660-304  2025-07-01              Stationery             Gift Set
# 111  102660-612  2025-07-01              Stationery             Gift Set
# 112  102647-001  2025-07-01              Stationery             Gift Set
# 113  102661-612  2025-07-01              Stationery             Gift Set
# 114  102175-050  2025-01-01                    Home              Kitchen
# 115  102523-001  2025-07-01              Stationery             Gift Set
# 116  102523-304  2025-07-01              Stationery             Gift Set
# 117  102516-001  2025-07-01                  Travel   Travel Accessories
# 118  102667-876  2025-07-01              Technology                Sound
# 119  102668-001  2025-07-01              Technology                Sound
# 120  102610-231  2025-07-01              Technology                Sound
# 121  102609-231  2025-07-01              Technology                Sound
# 122  102611-001  2025-07-01              Technology                Sound
# 123  106569-001  2025-07-01              Technology                Sound
# 124  102349-050  2025-01-01                    Home              Kitchen
# 125  102349-001  2025-01-01                    Home              Kitchen
# 126  102175-410  2025-01-01                    Home              Kitchen
# 127  102159-854  2024-07-01              Stationery             Notebook
# 128  102211-001  2025-01-01                    Home              Kitchen
# 129  102175-001  2025-01-01                    Home              Kitchen
# 130  102211-050  2025-01-01                    Home              Kitchen
# 131  102211-410  2025-01-01                    Home              Kitchen
# 132  101290-130  2022-06-01                    Food         All Occasion
# 133  101834-418  2024-01-01                  Travel                 Bags
# 134  102698-001  2025-07-01                 Duffels            Weekender
# 135  101290-920  2022-06-01                    Food         All Occasion
# 136  102682-913  2025-07-01               Drinkware   Everyday Hydration
# 137  102776-624  2025-07-01                 Duffels            Weekender
# 138  102685-228  2025-07-01               Drinkware   Everyday Hydration
# 139  101290-237  2022-06-01                    Food         All Occasion
# 140  102685-209  2025-07-01               Drinkware   Everyday Hydration
# 141  102682-650  2025-07-01               Drinkware   Everyday Hydration
# 142  102682-200  2025-07-01               Drinkware   Everyday Hydration
# 143  102070-590  2024-04-01                  Cooler  Hard Sides Personal
# 144  102234-610  2024-09-01                Backpack                Event
# 145  102290-155  2024-09-01     Blankets and Towels    Sport and Fitness
# 146  101596-231  2023-01-01                    Home                Decor
# 147         981  2022-06-01               Packaging            Kraft Box
# 148  102644-001  2025-07-01              Stationery             Notebook
# 149         977  2022-06-01               Packaging            Kraft Box
# 150  100805-078  2025-07-01  Slings and Waist Packs             Commuter
# 151  102034-143  2025-07-01                    Home              Kitchen
# 152  101412-763  2022-06-01               Drinkware     Active Hydration
# 153  101412-782  2022-06-01               Drinkware     Active Hydration
# 154  102234-410  2024-09-01                Backpack                Event
# 155  102645-001  2025-07-01              Stationery             Notebook
# 156  101357-100  2023-01-01               Drinkware       Coffee and Tea
# 157  102234-430  2024-09-01                Backpack                Event
# 158  102234-669  2024-09-01                Backpack                Event
# 159  102101-909  2025-07-01  Slings and Waist Packs             Commuter
# 160  102235-610  2024-09-01                Backpack                Event
# 161  102646-001  2025-07-01              Stationery             Notebook
# 162  102492-410  2025-07-01                  Travel         Organization
# 163  102235-430  2024-09-01                Backpack                Event
# 164  102235-669  2024-09-01                Backpack                Event
# 165  102234-001  2024-09-01                Backpack                Event
# 166  102235-001  2024-09-01                Backpack                Event
# 167  102234-723  2024-09-01                Backpack                Event
# 168  102234-387  2024-09-01                Backpack                Event
# 169  102235-410  2024-09-01                Backpack                Event
# 170  102234-828  2024-09-01                Backpack                Event
# 171  102234-518  2024-09-01                Backpack                Event
# 172  102070-946  2024-04-01                  Cooler  Hard Sides Personal
# 173  102492-001  2025-07-01                  Travel         Organization
# 174  102035-143  2025-07-01                  Travel         Organization
# 175  102492-430  2025-07-01                  Travel         Organization
# 176  101038-078  2025-07-01                  Travel         Organization
# 177  102492-669  2025-07-01                  Travel         Organization
# 178  102492-518  2025-07-01                  Travel         Organization
# 179  102492-828  2025-07-01                  Travel         Organization
# 180  102492-610  2025-07-01                  Travel         Organization
# 181  102492-387  2025-07-01                  Travel         Organization
# 182  102492-723  2025-07-01                  Travel         Organization
# 183  102649-001  2025-05-01               Umbrellas              Compact
# 184  102117-133  2024-07-01               Drinkware              Barware
# 185  102635-544  2025-04-01                    Home             Wellness
# 186  102495-001  2025-01-01              Technology                Sound
# 187  102539-001  2025-01-01              Technology                Sound
# 188  101032-410  2023-01-01                  Cooler  Soft Sides Personal
# 189  102165-111  2025-01-01     Blankets and Towels              Outdoor
# 190  101524-215  2022-06-01                    Food          Starter Kit
# 191  102649-635  2025-05-01               Umbrellas              Compact
# 192  102101-001  2025-01-01  Slings and Waist Packs             Commuter
# 193  102236-001  2024-09-01  Slings and Waist Packs                Event
# 194  101939-001  2024-04-01               Drinkware       Coffee and Tea
# 195  102236-610  2024-09-01  Slings and Waist Packs                Event
# 196  102236-410  2024-09-01  Slings and Waist Packs                Event
# 197  102236-430  2024-09-01  Slings and Waist Packs                Event
# 198  101930-130  2024-01-01                  Cooler     Soft Sides Event
# 199  100803-275  2023-04-01                  Travel         Organization
# 200  102659-635  2025-05-01               Umbrellas              Compact
# 201  101693-074  2023-04-01                 Outdoor     Patio and Picnic
# 202  102250-001  2025-01-01                Backpack             Commuter
# 203  102659-001  2025-05-01               Umbrellas              Compact
# 204  102099-001  2024-01-01              Technology                Sound
# 205  101998-100  2024-01-01               Drinkware   Everyday Hydration
# 206  102342-001  2025-01-01                  Cooler             Backpack
# 207  102290-001  2024-09-01     Blankets and Towels    Sport and Fitness
# 208  101998-006  2024-01-01               Drinkware   Everyday Hydration
# 209  102290-430  2024-09-01     Blankets and Towels    Sport and Fitness
# 210  101965-925  2024-07-01  Slings and Waist Packs               Travel
# 211         978  2022-06-01               Packaging            Kraft Box
# 212  101740-001  2024-07-01                  Office      Junior Padfolio
# 213  102442-743  2025-01-01                Backpack             Commuter
# 214  102089-001  2024-04-01               Drinkware       Coffee and Tea
# 215  102087-001  2024-04-01               Drinkware       Coffee and Tea
# 216  102338-610  2025-01-01                  Cooler                  Box
# 217  101727-001  2024-04-01                   Totes             Commuter
# 218  102160-218  2025-07-01     Blankets and Towels                 Home
# 219  101974-022  2025-04-01                 Outdoor                 Auto
# 220  101981-001  2025-04-01                 Outdoor                 Auto
# 221  102160-217  2025-07-01     Blankets and Towels                 Home
# 222  101756-539  2025-07-01     Blankets and Towels                 Home
# 223  101756-239  2025-07-01     Blankets and Towels                 Home
# 224  101973-022  2025-04-01                 Outdoor                 Auto
# 225  101975-022  2025-04-01                 Outdoor                 Auto
# 226  102251-001  2025-01-01                Backpack             Commuter
# 227  102635-705  2025-04-01                    Home             Wellness
# 228  101612-001  2023-06-01               Drinkware       Coffee and Tea
# 229  102551-001  2025-04-01                 Outdoor                 Auto
# 230  102443-001  2025-01-01                Backpack             Commuter
# 231  102251-410  2025-01-01                Backpack             Commuter
# 232  101475-021  2023-01-01                  Cooler  Soft Sides Personal
# 233  101608-001  2023-08-01                  Cooler     Soft Sides Event
# 234  101357-828  2025-01-01               Drinkware       Coffee and Tea
# 235  101033-410  2023-01-01                  Cooler  Soft Sides Personal
# 236  101611-001  2023-06-01               Drinkware       Coffee and Tea
# 237  102444-001  2025-01-01                Backpack             Commuter
# 238  101430-001  2023-08-01            Business Bag             Commuter
# 239  102600-791  2025-04-01               Drinkware   Everyday Hydration
# 240  101611-294  2023-06-01               Drinkware       Coffee and Tea
# 241  102600-009  2025-04-01               Drinkware   Everyday Hydration
# 242  102252-001  2025-01-01                Backpack             Commuter
# 243  102252-410  2025-01-01                Backpack             Commuter
# 244  102670-256  2025-04-01               Drinkware   Everyday Hydration
# 245  102670-022  2025-04-01               Drinkware   Everyday Hydration
# 246  102600-104  2025-04-01               Drinkware   Everyday Hydration
# 247  102670-255  2025-04-01               Drinkware   Everyday Hydration
# 248  102670-257  2025-04-01               Drinkware   Everyday Hydration
# 249  101998-022  2025-04-01               Drinkware   Everyday Hydration
# 250  101998-256  2025-04-01               Drinkware   Everyday Hydration
# 251  101998-255  2025-04-01               Drinkware   Everyday Hydration
# 252  102600-548  2025-04-01               Drinkware   Everyday Hydration
# 253  102404-022  2025-04-01               Drinkware     Active Hydration
# 254  101609-001  2023-08-01                  Cooler     Soft Sides Event
# 255  102654-001  2025-05-01               Drinkware   Everyday Hydration
# 256  102652-100  2025-05-01               Drinkware   Everyday Hydration
# 257  102345-430  2025-04-01               Drinkware     Active Hydration
# 258  102651-001  2025-05-01               Drinkware   Everyday Hydration
# 259  101608-794  2023-08-01                  Cooler     Soft Sides Event
# 260  102345-828  2025-04-01               Drinkware     Active Hydration
# 261  101901-059  2023-08-01                  Cooler     Soft Sides Event
# 262  101610-001  2023-08-01                  Cooler     Soft Sides Event
# 263  102404-256  2025-04-01               Drinkware     Active Hydration
# 264  102346-430  2025-04-01               Drinkware     Active Hydration
# 265  102066-001  2024-07-01                Backpack                Event
# 266  102404-255  2025-04-01               Drinkware     Active Hydration
# 267  100276-137  2025-01-01               Drinkware       Coffee and Tea
# 268  101737-001  2024-07-01                  Office      Junior Padfolio
# 269  101612-294  2023-06-01               Drinkware       Coffee and Tea
# 270  101725-231  2023-04-01                 Outdoor     Patio and Picnic
# 271  101609-794  2023-08-01                  Cooler     Soft Sides Event
# 272  102635-856  2025-04-01                    Home             Wellness
# 273  101357-430  2025-01-01               Drinkware       Coffee and Tea
# 274  102404-257  2025-04-01               Drinkware     Active Hydration
# 275  101357-669  2025-01-01               Drinkware       Coffee and Tea
# 276  101433-001  2023-08-01                  Office    Standard Padfolio
# 277  102346-828  2025-04-01               Drinkware     Active Hydration
# 278  100482-255  2025-04-01               Drinkware       Coffee and Tea
# 279  102654-848  2025-05-01               Drinkware   Everyday Hydration
# 280  102540-001  2025-01-01              Technology             Charging
# 281  100482-022  2025-04-01               Drinkware       Coffee and Tea
# 282  102651-100  2025-05-01               Drinkware   Everyday Hydration
# 283  102491-001  2025-01-01              Technology             Charging
# 284  102654-100  2025-05-01               Drinkware   Everyday Hydration
# 285  102652-407  2025-05-01               Drinkware   Everyday Hydration
# 286  100482-256  2025-04-01               Drinkware       Coffee and Tea
# 287  102652-001  2025-05-01               Drinkware   Everyday Hydration
# 288  102651-407  2025-05-01               Drinkware   Everyday Hydration
# 289  102140-944  2024-04-01               Drinkware   Everyday Hydration
# 290  102140-100  2024-04-01               Drinkware   Everyday Hydration
# 291  101222-973  2025-01-01     Blankets and Towels              Outdoor
# 292  101964-925  2024-07-01                 Duffels            Weekender
# 293  100177-777  2022-06-01                  Cooler     Soft Sides Event
# 294  102590-100  2025-04-01                  Cooler  Soft Sides Personal
# 295  102106-088  2024-04-01               Drinkware   Everyday Hydration
# 296  101910-001  2024-01-01              Technology                Sound
# 297  101036-410  2023-01-01                   Totes                Event
# 298  101726-492  2024-01-01               Drinkware     Active Hydration
# 299  102063-001  2024-07-01                Backpack                Event
#
#      Sales_Pre_Intro  Sales_Post_Intro  New_SKU_Sales  \
# 0            28833.0               0.0            0.0
# 1            28833.0               0.0            0.0
# 2            28833.0               0.0            0.0
# 3            28833.0               0.0            0.0
# 4            28833.0               0.0            0.0
# 5            35105.0               0.0            0.0
# 6            34926.0               0.0            0.0
# 7            15493.0               0.0            0.0
# 8            35286.0               0.0            0.0
# 9            35340.0               0.0            0.0
# 10           35340.0               0.0            0.0
# 11           35286.0               0.0            0.0
# 12           21002.0               0.0            0.0
# 13           20856.0               0.0            0.0
# 14           20806.0               0.0            0.0
# 15           21002.0               0.0            0.0
# 16           15493.0               0.0            0.0
# 17            2328.0              20.0          647.0
# 18           81799.0            5434.0            5.0
# 19           81799.0            5438.0            1.0
# 20            2913.0             300.0           84.0
# 21            9522.0            1060.0         1491.0
# 22            2380.0             274.0         1396.0
# 23           33418.0            4830.0          637.0
# 24             898.0             132.0            5.0
# 25             898.0             136.0            1.0
# 26           33418.0            5213.0          254.0
# 27           33418.0            5450.0           17.0
# 28           33418.0            5456.0           11.0
# 29           33418.0            5462.0            5.0
# 30            6258.0            1106.0           10.0
# 31            6258.0            1112.0            4.0
# 32            2443.0             476.0         5951.0
# 33            1320.0             263.0           36.0
# 34           39649.0            8732.0            0.0
# 35            1320.0             292.0            7.0
# 36           30104.0            6740.0          276.0
# 37            1610.0             374.0           32.0
# 38           30104.0            7015.0            1.0
# 39           25355.0            5920.0           58.0
# 40           31699.0            7462.0          971.0
# 41           25355.0            5971.0            7.0
# 42           25355.0            5977.0            1.0
# 43            1610.0             387.0           19.0
# 44            1610.0             402.0            4.0
# 45            1610.0             405.0            1.0
# 46           17833.0            4490.0          122.0
# 47           17833.0            4534.0           78.0
# 48           17833.0            4588.0           24.0
# 49           17833.0            4589.0           23.0
# 50           17833.0            4590.0           22.0
# 51           17833.0            4590.0           22.0
# 52           17833.0            4590.0           22.0
# 53           17833.0            4592.0           20.0
# 54           17833.0            4605.0            7.0
# 55           17833.0            4606.0            6.0
# 56           17833.0            4608.0            4.0
# 57           17833.0            4610.0            2.0
# 58           31699.0            8331.0          102.0
# 59           31699.0            8381.0           52.0
# 60           31699.0            8432.0            1.0
# 61           31699.0            8433.0            0.0
# 62           31699.0            8433.0            0.0
# 63            1994.0             557.0          105.0
# 64            1994.0             565.0           97.0
# 65           10427.0            3030.0          207.0
# 66            1994.0             596.0           66.0
# 67            3643.0            1160.0           47.0
# 68           27281.0            8974.0           65.0
# 69            3643.0            1203.0            4.0
# 70            3643.0            1206.0            1.0
# 71            3643.0            1206.0            1.0
# 72              17.0               6.0           49.0
# 73            4207.0            1554.0         2096.0
# 74            8327.0            3147.0         1338.0
# 75            5841.0            2233.0           17.0
# 76           16781.0            6449.0           21.0
# 77            5841.0            2248.0            2.0
# 78            5841.0            2248.0            2.0
# 79          220989.0           85103.0          937.0
# 80           16764.0            6459.0           11.0
# 81           16781.0            6468.0            2.0
# 82           16781.0            6470.0            0.0
# 83           16781.0            6470.0            0.0
# 84          220989.0           85682.0          358.0
# 85          220989.0           85688.0          352.0
# 86          220989.0           85976.0           64.0
# 87          220989.0           86037.0            3.0
# 88          220989.0           86038.0            2.0
# 89          220989.0           86039.0            1.0
# 90          220989.0           86039.0            1.0
# 91             164.0              65.0           18.0
# 92           19272.0            7711.0           91.0
# 93           19272.0            7747.0           55.0
# 94           19272.0            7750.0           52.0
# 95           19272.0            7751.0           51.0
# 96           19272.0            7752.0           50.0
# 97           19272.0            7776.0           26.0
# 98           19272.0            7792.0           10.0
# 99            1484.0             605.0           36.0
# 100          14057.0            5740.0          769.0
# 101          10259.0            4195.0          507.0
# 102          14101.0            6297.0          212.0
# 103          10259.0            4630.0           72.0
# 104           8668.0            3941.0          863.0
# 105          14861.0            6765.0          411.0
# 106          10259.0            4696.0            6.0
# 107           3296.0            1518.0           72.0
# 108           2299.0            1069.0            9.0
# 109           2299.0            1072.0            6.0
# 110           2299.0            1074.0            4.0
# 111           2299.0            1076.0            2.0
# 112           2299.0            1076.0            2.0
# 113           2299.0            1077.0            1.0
# 114          14861.0            6965.0          211.0
# 115           2299.0            1078.0            0.0
# 116           2299.0            1078.0            0.0
# 117          14156.0            6692.0            1.0
# 118          17962.0            8620.0           27.0
# 119          17962.0            8622.0           25.0
# 120          17962.0            8639.0            8.0
# 121          17962.0            8643.0            4.0
# 122          17962.0            8644.0            3.0
# 123          17962.0            8645.0            2.0
# 124          14861.0            7157.0           19.0
# 125          14861.0            7157.0           19.0
# 126          14861.0            7159.0           17.0
# 127           3277.0            1579.0           11.0
# 128          14861.0            7169.0            7.0
# 129          14861.0            7170.0            6.0
# 130          14861.0            7170.0            6.0
# 131          14861.0            7173.0            3.0
# 132          14811.0            7227.0          192.0
# 133            786.0             384.0          138.0
# 134           2813.0            1396.0            9.0
# 135          14811.0            7353.0           66.0
# 136          24318.0           12104.0           77.0
# 137           2813.0            1405.0            0.0
# 138          24318.0           12158.0           23.0
# 139          14811.0            7405.0           14.0
# 140          24318.0           12173.0            8.0
# 141          24318.0           12173.0            8.0
# 142          24318.0           12175.0            6.0
# 143           5816.0            2972.0         1013.0
# 144          15784.0            8106.0          805.0
# 145           3231.0            1683.0          804.0
# 146           6891.0            3617.0          926.0
# 147           8221.0            4411.0           74.0
# 148           7109.0            3850.0          155.0
# 149           7139.0            3867.0          618.0
# 150          11942.0            6545.0          165.0
# 151           7835.0            4298.0           32.0
# 152           8668.0            4804.0            0.0
# 153           8668.0            4804.0            0.0
# 154          15784.0            8759.0          152.0
# 155           7109.0            3974.0           31.0
# 156           5463.0            3056.0         3104.0
# 157          15784.0            8834.0           77.0
# 158          15784.0            8835.0           76.0
# 159          11942.0            6702.0            8.0
# 160          15784.0            8859.0           52.0
# 161           7109.0            4003.0            2.0
# 162          78245.0           44122.0         2168.0
# 163          15784.0            8905.0            6.0
# 164          15784.0            8905.0            6.0
# 165          15784.0            8907.0            4.0
# 166          15784.0            8907.0            4.0
# 167          15784.0            8909.0            2.0
# 168          15784.0            8909.0            2.0
# 169          15784.0            8909.0            2.0
# 170          15784.0            8910.0            1.0
# 171          15784.0            8910.0            1.0
# 172           5816.0            3301.0          684.0
# 173          78245.0           44613.0         1677.0
# 174          78173.0           45623.0          667.0
# 175          78245.0           45990.0          300.0
# 176          78245.0           46150.0          140.0
# 177          78245.0           46237.0           53.0
# 178          78245.0           46238.0           52.0
# 179          78245.0           46238.0           52.0
# 180          78245.0           46283.0            7.0
# 181          78245.0           46287.0            3.0
# 182          78245.0           46290.0            0.0
# 183           9750.0            5769.0         1078.0
# 184          21707.0           12956.0          327.0
# 185           3291.0            2007.0         1573.0
# 186          23733.0           14541.0          999.0
# 187          23733.0           14721.0          819.0
# 188          11556.0            7191.0         3133.0
# 189           3885.0            2427.0         1266.0
# 190            541.0             341.0           17.0
# 191           9750.0            6292.0          555.0
# 192          15165.0            9894.0          263.0
# 193          31799.0           20844.0          879.0
# 194           8575.0            5717.0         1080.0
# 195          31799.0           21306.0          417.0
# 196          31799.0           21427.0          296.0
# 197          31798.0           21600.0          123.0
# 198          25467.0           17327.0          381.0
# 199          14924.0           10185.0         3447.0
# 200           9750.0            6669.0          178.0
# 201           2709.0            1858.0          797.0
# 202          17771.0           12387.0         2932.0
# 203           9750.0            6816.0           31.0
# 204           7568.0            5292.0         3049.0
# 205          24524.0           17279.0          968.0
# 206            955.0             674.0         1959.0
# 207           3250.0            2307.0          180.0
# 208          24524.0           17535.0          712.0
# 209           3249.0            2354.0          133.0
# 210           4284.0            3115.0          557.0
# 211           2743.0            2030.0         2455.0
# 212            439.0             330.0           77.0
# 213          17752.0           13833.0         1486.0
# 214           8575.0            6758.0           39.0
# 215           8575.0            6782.0           15.0
# 216           2742.0            2180.0           72.0
# 217            345.0             275.0          146.0
# 218           9977.0            8021.0          112.0
# 219          10906.0            8792.0          245.0
# 220          10905.0            8845.0          192.0
# 221           9960.0            8096.0           37.0
# 222           9977.0            8113.0           20.0
# 223           9960.0            8101.0           32.0
# 224          10905.0            8921.0          116.0
# 225          10904.0            8927.0          110.0
# 226          17771.0           14582.0          737.0
# 227           3290.0            2707.0          873.0
# 228           6606.0            5437.0          721.0
# 229          10906.0            8987.0           50.0
# 230          17771.0           14680.0          639.0
# 231          17771.0           14782.0          537.0
# 232          11556.0            9760.0          564.0
# 233          24125.0           20471.0         1765.0
# 234          19131.0           16250.0         1355.0
# 235          11555.0            9835.0          489.0
# 236           6606.0            5623.0          535.0
# 237          17752.0           15116.0          203.0
# 238            389.0             334.0          143.0
# 239          21629.0           18588.0          259.0
# 240           6606.0            5685.0          473.0
# 241          21648.0           18649.0          198.0
# 242          17771.0           15311.0            8.0
# 243          17771.0           15313.0            6.0
# 244          21648.0           18657.0          190.0
# 245          21648.0           18703.0          144.0
# 246          21648.0           18741.0          106.0
# 247          21648.0           18776.0           71.0
# 248          21648.0           18797.0           50.0
# 249          21648.0           18808.0           39.0
# 250          21648.0           18814.0           33.0
# 251          21648.0           18838.0            9.0
# 252          21629.0           18836.0           11.0
# 253          22279.0           19423.0         1066.0
# 254          24125.0           21506.0          730.0
# 255          26605.0           23787.0         1083.0
# 256          26605.0           23787.0         1083.0
# 257          22260.0           19987.0          502.0
# 258          26605.0           23909.0          961.0
# 259          24125.0           21713.0          523.0
# 260          22279.0           20079.0          410.0
# 261          24125.0           21759.0          477.0
# 262          24125.0           21777.0          459.0
# 263          22279.0           20175.0          314.0
# 264          22279.0           20182.0          307.0
# 265          12183.0           11049.0         2396.0
# 266          22260.0           20206.0          283.0
# 267          19150.0           17395.0          210.0
# 268            439.0             399.0            8.0
# 269           6606.0            6020.0          138.0
# 270           2730.0            2493.0          162.0
# 271          24125.0           22080.0          156.0
# 272           3291.0            3014.0          566.0
# 273          19149.0           17547.0           58.0
# 274          22279.0           20452.0           37.0
# 275          19150.0           17598.0            7.0
# 276          20999.0           19305.0          181.0
# 277          22260.0           20483.0            6.0
# 278          16918.0           15738.0           68.0
# 279          26605.0           24786.0           84.0
# 280          22365.0           20852.0          854.0
# 281          16918.0           15777.0           29.0
# 282          26605.0           24817.0           53.0
# 283          22346.0           20846.0          860.0
# 284          26605.0           24821.0           49.0
# 285          26605.0           24842.0           28.0
# 286          16918.0           15803.0            3.0
# 287          26605.0           24866.0            4.0
# 288          26605.0           24869.0            1.0
# 289          14794.0           13833.0          547.0
# 290          14794.0           13899.0          481.0
# 291           3904.0            3685.0            8.0
# 292            395.0             373.0          924.0
# 293           8316.0            7867.0         1871.0
# 294          25471.0           24237.0          439.0
# 295          14794.0           14274.0          106.0
# 296           7568.0            7379.0          962.0
# 297           1509.0            1478.0         3798.0
# 298           8476.0            8328.0         2660.0
# 299          12678.0           12676.0          769.0
#
#      Delta_Sales_Excl_New_SKU
# 0                   -1.000000
# 1                   -1.000000
# 2                   -1.000000
# 3                   -1.000000
# 4                   -1.000000
# 5                   -1.000000
# 6                   -1.000000
# 7                   -1.000000
# 8                   -1.000000
# 9                   -1.000000
# 10                  -1.000000
# 11                  -1.000000
# 12                  -1.000000
# 13                  -1.000000
# 14                  -1.000000
# 15                  -1.000000
# 16                  -1.000000
# 17                  -0.991409
# 18                  -0.933569
# 19                  -0.933520
# 20                  -0.897013
# 21                  -0.888679
# 22                  -0.884874
# 23                  -0.855467
# 24                  -0.853007
# 25                  -0.848552
# 26                  -0.844006
# 27                  -0.836914
# 28                  -0.836735
# 29                  -0.836555
# 30                  -0.823266
# 31                  -0.822307
# 32                  -0.805158
# 33                  -0.800758
# 34                  -0.779767
# 35                  -0.778788
# 36                  -0.776109
# 37                  -0.767702
# 38                  -0.766974
# 39                  -0.766515
# 40                  -0.764598
# 41                  -0.764504
# 42                  -0.764267
# 43                  -0.759627
# 44                  -0.750311
# 45                  -0.748447
# 46                  -0.748220
# 47                  -0.745752
# 48                  -0.742724
# 49                  -0.742668
# 50                  -0.742612
# 51                  -0.742612
# 52                  -0.742612
# 53                  -0.742500
# 54                  -0.741771
# 55                  -0.741715
# 56                  -0.741603
# 57                  -0.741490
# 58                  -0.737184
# 59                  -0.735607
# 60                  -0.733998
# 61                  -0.733966
# 62                  -0.733966
# 63                  -0.720662
# 64                  -0.716650
# 65                  -0.709408
# 66                  -0.701103
# 67                  -0.681581
# 68                  -0.671053
# 69                  -0.669778
# 70                  -0.668954
# 71                  -0.668954
# 72                  -0.647059
# 73                  -0.630616
# 74                  -0.622073
# 75                  -0.617702
# 76                  -0.615696
# 77                  -0.615134
# 78                  -0.615134
# 79                  -0.614899
# 80                  -0.614710
# 81                  -0.614564
# 82                  -0.614445
# 83                  -0.614445
# 84                  -0.612279
# 85                  -0.612252
# 86                  -0.610949
# 87                  -0.610673
# 88                  -0.610668
# 89                  -0.610664
# 90                  -0.610664
# 91                  -0.603659
# 92                  -0.599886
# 93                  -0.598018
# 94                  -0.597862
# 95                  -0.597810
# 96                  -0.597758
# 97                  -0.596513
# 98                  -0.595683
# 99                  -0.592318
# 100                 -0.591663
# 101                 -0.591091
# 102                 -0.553436
# 103                 -0.548689
# 104                 -0.545339
# 105                 -0.544782
# 106                 -0.542256
# 107                 -0.539442
# 108                 -0.535015
# 109                 -0.533710
# 110                 -0.532840
# 111                 -0.531970
# 112                 -0.531970
# 113                 -0.531535
# 114                 -0.531324
# 115                 -0.531100
# 116                 -0.531100
# 117                 -0.527268
# 118                 -0.520098
# 119                 -0.519987
# 120                 -0.519040
# 121                 -0.518818
# 122                 -0.518762
# 123                 -0.518706
# 124                 -0.518404
# 125                 -0.518404
# 126                 -0.518269
# 127                 -0.518157
# 128                 -0.517596
# 129                 -0.517529
# 130                 -0.517529
# 131                 -0.517327
# 132                 -0.512052
# 133                 -0.511450
# 134                 -0.503733
# 135                 -0.503545
# 136                 -0.502262
# 137                 -0.500533
# 138                 -0.500041
# 139                 -0.500034
# 140                 -0.499424
# 141                 -0.499424
# 142                 -0.499342
# 143                 -0.488996
# 144                 -0.486442
# 145                 -0.479109
# 146                 -0.475112
# 147                 -0.463447
# 148                 -0.458433
# 149                 -0.458327
# 150                 -0.451934
# 151                 -0.451436
# 152                 -0.445778
# 153                 -0.445778
# 154                 -0.445071
# 155                 -0.440990
# 156                 -0.440600
# 157                 -0.440319
# 158                 -0.440256
# 159                 -0.438787
# 160                 -0.438735
# 161                 -0.436911
# 162                 -0.436105
# 163                 -0.435821
# 164                 -0.435821
# 165                 -0.435694
# 166                 -0.435694
# 167                 -0.435568
# 168                 -0.435568
# 169                 -0.435568
# 170                 -0.435504
# 171                 -0.435504
# 172                 -0.432428
# 173                 -0.429829
# 174                 -0.416384
# 175                 -0.412231
# 176                 -0.410186
# 177                 -0.409074
# 178                 -0.409061
# 179                 -0.409061
# 180                 -0.408486
# 181                 -0.408435
# 182                 -0.408397
# 183                 -0.408308
# 184                 -0.403142
# 185                 -0.390155
# 186                 -0.387309
# 187                 -0.379724
# 188                 -0.377726
# 189                 -0.375290
# 190                 -0.369686
# 191                 -0.354667
# 192                 -0.347577
# 193                 -0.344508
# 194                 -0.333294
# 195                 -0.329979
# 196                 -0.326174
# 197                 -0.320712
# 198                 -0.319629
# 199                 -0.317542
# 200                 -0.316000
# 201                 -0.314138
# 202                 -0.302966
# 203                 -0.300923
# 204                 -0.300740
# 205                 -0.295425
# 206                 -0.294241
# 207                 -0.290154
# 208                 -0.284986
# 209                 -0.275469
# 210                 -0.272876
# 211                 -0.259934
# 212                 -0.248292
# 213                 -0.220764
# 214                 -0.211895
# 215                 -0.209096
# 216                 -0.204960
# 217                 -0.202899
# 218                 -0.196051
# 219                 -0.193838
# 220                 -0.188904
# 221                 -0.187149
# 222                 -0.186830
# 223                 -0.186647
# 224                 -0.181935
# 225                 -0.181310
# 226                 -0.179450
# 227                 -0.177204
# 228                 -0.176960
# 229                 -0.175958
# 230                 -0.173935
# 231                 -0.168195
# 232                 -0.155417
# 233                 -0.151461
# 234                 -0.150593
# 235                 -0.148853
# 236                 -0.148804
# 237                 -0.148490
# 238                 -0.141388
# 239                 -0.140598
# 240                 -0.139419
# 241                 -0.138535
# 242                 -0.138428
# 243                 -0.138315
# 244                 -0.138165
# 245                 -0.136040
# 246                 -0.134285
# 247                 -0.132668
# 248                 -0.131698
# 249                 -0.131190
# 250                 -0.130913
# 251                 -0.129804
# 252                 -0.129132
# 253                 -0.128192
# 254                 -0.108560
# 255                 -0.105920
# 256                 -0.105920
# 257                 -0.102111
# 258                 -0.101334
# 259                 -0.099979
# 260                 -0.098748
# 261                 -0.098073
# 262                 -0.097326
# 263                 -0.094439
# 264                 -0.094125
# 265                 -0.093081
# 266                 -0.092273
# 267                 -0.091645
# 268                 -0.091116
# 269                 -0.088707
# 270                 -0.086813
# 271                 -0.084767
# 272                 -0.084169
# 273                 -0.083660
# 274                 -0.082005
# 275                 -0.081044
# 276                 -0.080671
# 277                 -0.079829
# 278                 -0.069748
# 279                 -0.068371
# 280                 -0.067650
# 281                 -0.067443
# 282                 -0.067205
# 283                 -0.067126
# 284                 -0.067055
# 285                 -0.066266
# 286                 -0.065906
# 287                 -0.065364
# 288                 -0.065251
# 289                 -0.064959
# 290                 -0.060497
# 291                 -0.056096
# 292                 -0.055696
# 293                 -0.053992
# 294                 -0.048447
# 295                 -0.035149
# 296                 -0.024974
# 297                 -0.020543
# 298                 -0.017461
# 299                 -0.000158

# %%
# ===============================================================
# 🧮 Block 12 (simple): z-score filter vs pre 3-mo subcategory totals
# ===============================================================
Z_MIN = -0.5
MIN_NEW_UNITS = 50
HIST_MONTHS = 12

def pre_three_month_stats(cat, sub, new_item, intro_month):
    intro_ts  = pd.Timestamp(intro_month).to_period('M').to_timestamp()
    start_hist = (intro_ts - pd.DateOffset(months=HIST_MONTHS)).to_period('M').to_timestamp()
    end_hist   = (intro_ts - pd.DateOffset(months=1)).to_period('M').to_timestamp()

    m = monthly[
        (monthly['Category (Expanded)'] == cat) &
        (monthly['Subcategory Desc']    == sub) &
        (monthly['Month'] >= start_hist) & (monthly['Month'] <= end_hist) &
        (monthly['Item'] != new_item)
    ].copy()

    if m.empty:
        return 0.0, 1.0

    idx = pd.period_range(start_hist, end_hist, freq='M').to_timestamp()
    sub_tot_by_m = (m.groupby('Month')['SalesQty'].sum()
                      .reindex(idx, fill_value=0.0))

    sub_tot_3mo = sub_tot_by_m.rolling(3, min_periods=3).sum().dropna()
    if len(sub_tot_3mo) == 0:
        return 0.0, 1.0

    mu = float(sub_tot_3mo.mean())
    sigma = float(sub_tot_3mo.std(ddof=1)) if len(sub_tot_3mo) > 1 else 1.0
    if sigma == 0:
        sigma = 1.0
    return mu, sigma

def new_post_three_month_total(new_item, intro_month):
    base = pd.Timestamp(intro_month).to_period('M').to_timestamp()
    post_months = [(base + pd.DateOffset(months=i)).to_period('M').to_timestamp() for i in [1,2,3]]
    mask = (monthly['Item'] == new_item) & (monthly['Month'].isin(post_months))
    return float(monthly.loc[mask, 'SalesQty'].sum())

rows = []
for _, ev in canni_subcat.iterrows():
    cat, sub  = ev['Category (Expanded)'], ev['Subcategory Desc']
    new_item  = ev['Item_New']
    intro_m   = ev['Intro_Month']

    mu, sigma = pre_three_month_stats(cat, sub, new_item, intro_m)
    s_new     = new_post_three_month_total(new_item, intro_m)
    z         = (s_new - mu) / sigma if sigma != 0 else -999.0

    keep = (
        (s_new >= MIN_NEW_UNITS) and
        (z >= Z_MIN) and
        pd.notna(ev['Delta_Sales_Excl_New_SKU']) and
        (ev['Delta_Sales_Excl_New_SKU'] < 0)
    )

    # 👇 THIS MUST BE INSIDE THE LOOP
    rows.append({
        **ev.to_dict(),
        'Pre_3M_Means': mu,
        'Pre_3M_STDs':  sigma,
        'Zscore_vs_Pre_3M': z,
        'Keep_by_Z': keep
    })

canni_z = pd.DataFrame(rows)

# quick diagnostics (optional)
print("Events total:", len(canni_subcat))
print("Rows built:", len(canni_z))
if not canni_z.empty:
    print("Keep_by_Z counts:\n", canni_z['Keep_by_Z'].value_counts(dropna=False))

canni_final = (
    canni_z[canni_z['Keep_by_Z']]
    .sort_values(['Category (Expanded)', 'Subcategory Desc', 'Intro_Month'])
    .reset_index(drop=True)
)

display(canni_final[
    ['Item_New','Intro_Month','Category (Expanded)','Subcategory Desc',
     'Pre_3M_Means','Pre_3M_STDs',
     'Sales_Pre_Intro','Sales_Post_Intro','New_SKU_Sales','Delta_Sales_Excl_New_SKU',
     'Zscore_vs_Pre_3M']
])
# Out:
# Events total: 1431
# Rows built: 1431
# Keep_by_Z counts:
#  Keep_by_Z
# False    1412
# True       19
# Name: count, dtype: int64
#       Item_New Intro_Month     Category (Expanded)   Subcategory Desc  \
# 0   100988-941  2024-07-01     Blankets and Towels            Outdoor
# 1   102290-155  2024-09-01     Blankets and Towels  Sport and Fitness
# 2   102342-001  2025-01-01                  Cooler           Backpack
# 3   102338-610  2025-01-01                  Cooler                Box
# 4   100177-777  2022-06-01                  Cooler   Soft Sides Event
# 5   101357-100  2023-01-01               Drinkware     Coffee and Tea
# 6   101964-925  2024-07-01                 Duffels          Weekender
# 7   101596-231  2023-01-01                    Home              Decor
# 8   101620-214  2023-01-01                    Home      Entertainment
# 9   101740-001  2024-07-01                  Office    Junior Padfolio
# 10         978  2022-06-01               Packaging          Kraft Box
# 11         980  2022-06-01               Packaging          Kraft Box
# 12  100805-275  2023-04-01  Slings and Waist Packs           Commuter
# 13  101276-001  2022-04-01              Stationery           Notebook
# 14  101910-001  2024-01-01              Technology              Sound
# 15  102099-001  2024-01-01              Technology              Sound
# 16  101727-001  2024-04-01                   Totes           Commuter
# 17  101036-410  2023-01-01                   Totes              Event
# 18  101210-001  2022-06-01                  Travel       Organization
#
#     Pre_3M_Means  Pre_3M_STDs  Sales_Pre_Intro  Sales_Post_Intro  \
# 0         2156.0   881.299798           4207.0            1554.0
# 1          801.3  1037.440874           3231.0            1683.0
# 2          197.4   354.647305            955.0             674.0
# 3          521.8  1069.965815           2742.0            2180.0
# 4         1380.8  2758.626462           8316.0            7867.0
# 5         2187.1  2250.506533           5463.0            3056.0
# 6          124.1   139.310564            395.0             373.0
# 7         1134.0  2214.405664           6891.0            3617.0
# 8         1083.9  1143.479821           2328.0              20.0
# 9           96.5   169.556448            439.0             330.0
# 10         688.2   916.479836           2743.0            2030.0
# 11        2319.4  3156.464062           8327.0            3147.0
# 12         654.8  1050.780641           2443.0             476.0
# 13         513.5   870.669889           2380.0             274.0
# 14        1861.1  2807.744071           7568.0            7379.0
# 15        1861.1  2807.744071           7568.0            5292.0
# 16         175.7   159.088410            345.0             275.0
# 17        1583.1  1495.268794           1509.0            1478.0
# 18        2461.7  3807.987251           9522.0            1060.0
#
#     New_SKU_Sales  Delta_Sales_Excl_New_SKU  Zscore_vs_Pre_3M
# 0          2096.0                 -0.630616         -0.068081
# 1           804.0                 -0.479109          0.002603
# 2          1959.0                 -0.294241          4.967188
# 3            72.0                 -0.204960         -0.420387
# 4          1871.0                 -0.053992          0.177697
# 5          3104.0                 -0.440600          0.407419
# 6           924.0                 -0.055696          5.741847
# 7           926.0                 -0.475112         -0.093930
# 8           647.0                 -0.991409         -0.382079
# 9            77.0                 -0.248292         -0.115006
# 10         2455.0                 -0.259934          1.927811
# 11         1338.0                 -0.622073         -0.310918
# 12         5951.0                 -0.805158          5.040253
# 13         1396.0                 -0.884874          1.013587
# 14          962.0                 -0.024974         -0.320221
# 15         3049.0                 -0.300740          0.423080
# 16          146.0                 -0.202899         -0.186689
# 17         3798.0                 -0.020543          1.481272
# 18         1491.0                 -0.888679         -0.254912

# %%
# ===============================================================
# 📘 TABLE 1 — COLUMN HEADER DEFINITIONS
# ===============================================================

col_defs = pd.DataFrame([
    ["Item_New", "The newly introduced SKU."],
    ["Intro_Month", "Month the SKU first entered the market (parsed intro code)."],
    ["Category (Expanded)", "Full category name mapped from category code."],
    ["Subcategory Desc", "Subcategory where cannibalization is measured."],
    ["Pre_3M_Means", "Average of rolling 3-month subcategory totals from the prior 12 months (seasonality baseline)."],
    ["Pre_3M_STDs", "Standard deviation of those rolling 3-month totals (subcategory volatility)."],
    ["Sales_Pre_Intro", "Total sales of existing SKUs in the 3 months BEFORE intro."],
    ["Sales_Post_Intro", "Total sales of existing SKUs in the 3 months AFTER intro."],
    ["New_SKU_Sales", "Sales of the new SKU in the same 3-month post-intro window."],
    ["Delta_Sales_Excl_New_SKU", "Percent change in existing SKU sales (Post vs Pre). Negative indicates decline."],
    ["Zscore_vs_Pre_3M", "Seasonality-adjusted strength of the intro compared to historical norms."]
], columns=["Column", "Meaning"])


# ===============================================================
# 📗 TABLE 2 — PARAMETER SETTINGS + MEANINGS
# ===============================================================

param_defs = pd.DataFrame([
    ["MIN_NEW_UNITS", 50,
     "Minimum number of units the new SKU must sell in its first 3 months to be considered meaningful."],

    ["Z_MIN", -1,
     "Minimum Z-score allowed. Intro must sell within 1 standard deviation of normal subcategory demand."],

    ["HIST_MONTHS", 12,
     "Amount of historical data (months) used to compute rolling 3-month averages & std dev for seasonality."]
], columns=["Parameter", "Value", "Meaning"])


# ===============================================================
# 📙 TABLE 3 — HOW TO INTERPRET THE Z-SCORE
# ===============================================================

z_explain = pd.DataFrame([
    ["Z > 0", "New SKU sold ABOVE typical seasonal subcategory volume → strong intro."],
    ["0 ≥ Z > -1", "New SKU sold BELOW typical volume but still within normal range → moderate intro."],
    ["Z ≤ -1", "New SKU sold FAR BELOW seasonal norms → likely too weak to cause cannibalization."]
],
columns=["Z-score Range", "Interpretation"])


# ===============================================================
# ✅ DISPLAY TABLES
# ===============================================================

print("\nCOLUMN DEFINITIONS:")
display(col_defs)

print("\nPARAMETER DEFINITIONS:")
display(param_defs)

print("\nZ-SCORE INTERPRETATION:")
display(z_explain)
# Out:
# COLUMN DEFINITIONS:
#                       Column  \
# 0                   Item_New
# 1                Intro_Month
# 2        Category (Expanded)
# 3           Subcategory Desc
# 4               Pre_3M_Means
# 5                Pre_3M_STDs
# 6            Sales_Pre_Intro
# 7           Sales_Post_Intro
# 8              New_SKU_Sales
# 9   Delta_Sales_Excl_New_SKU
# 10          Zscore_vs_Pre_3M
#
#                                                                                            Meaning
# 0                                                                        The newly introduced SKU.
# 1                                      Month the SKU first entered the market (parsed intro code).
# 2                                                    Full category name mapped from category code.
# 3                                                   Subcategory where cannibalization is measured.
# 4   Average of rolling 3-month subcategory totals from the prior 12 months (seasonality baseline).
# 5                     Standard deviation of those rolling 3-month totals (subcategory volatility).
# 6                                       Total sales of existing SKUs in the 3 months BEFORE intro.
# 7                                        Total sales of existing SKUs in the 3 months AFTER intro.
# 8                                      Sales of the new SKU in the same 3-month post-intro window.
# 9                  Percent change in existing SKU sales (Post vs Pre). Negative indicates decline.
# 10                        Seasonality-adjusted strength of the intro compared to historical norms.
# PARAMETER DEFINITIONS:
#        Parameter  Value  \
# 0  MIN_NEW_UNITS     50
# 1          Z_MIN     -1
# 2    HIST_MONTHS     12
#
#                                                                                                   Meaning
# 0        Minimum number of units the new SKU must sell in its first 3 months to be considered meaningful.
# 1      Minimum Z-score allowed. Intro must sell within 1 standard deviation of normal subcategory demand.
# 2  Amount of historical data (months) used to compute rolling 3-month averages & std dev for seasonality.
# Z-SCORE INTERPRETATION:
#   Z-score Range  \
# 0         Z > 0
# 1    0 ≥ Z > -1
# 2        Z ≤ -1
#
#                                                                       Interpretation
# 0             New SKU sold ABOVE typical seasonal subcategory volume → strong intro.
# 1  New SKU sold BELOW typical volume but still within normal range → moderate intro.
# 2  New SKU sold FAR BELOW seasonal norms → likely too weak to cause cannibalization.

# %%
# ===============================================================
# EXPORT canni_final TO EXCEL (GOOGLE COLAB DOWNLOAD)
# ===============================================================

output_file = "canni_final.xlsx"

# Save raw table (not styled)
canni_final.to_excel(output_file, index=False)

# Force download in Google Colab
from google.colab import files
files.download(output_file)
